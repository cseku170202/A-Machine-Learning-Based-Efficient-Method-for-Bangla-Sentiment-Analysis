# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
import pandas as pd
from nltk.stem import WordNetLemmatizer
from imblearn.over_sampling import SMOTE

from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import GlobalMaxPooling1D
from keras.layers import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
movie_reviews = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/new_data.csv")

movie_reviews.isnull().values.any()

movie_reviews.shape
# Out:
# (22788, 2)

# %%
movie_reviews.head(20)
# Out:
#                                              comments sentiment
# 0   ~~মা শিক্ষিত না হলেও   ~~মায়ের শিক্ষা কখনো ছোট...  Positive
# 1   ৭বছর পর সাকিব খানের কোন ছবি দেখলাম।। এক কথায় অ...  Positive
# 2   আমার দেখা ইমনের সেরা অভিনয় এই মুভিতে  আর শাকিব...  Positive
# 3   আমার জিবনে প্রথম মুভি যে হলে গিয়ে দেখলাম ওনেক ...  Positive
# 4   সেই ২০১৯ থেকে অপেক্ষায় ছিলাম কবে ইউটিউবে আসবে ...  Positive
# 5             শাকিব খানের এই মুভিটি অনেক সুন্দর হয়েছে  Positive
# 6   বাংলা মুভির পাশে থাকার জন্য সবাইকে অসংখ্য ধন্য...  Positive
# 7   সময়ের সেরা ছবি পাসওয়ার্ড,সবাই বেশি বেশি দেখুন ...  Positive
# 8       বাংলাদেশের কিছুর অভাব  থাকলেও পাগলের অভাব নেই  Negative
# 9          শাকিব খান  ছাড়া কোনো কথা হবে না ইনশাআল্লাহ  Positive
# 10  যখন আমি বাংলা মুভি দেখি কেন যেন হতাশ হয়ে যায়...  Negative
# 11  সিনেমাটি হলে গিয়ে দেখা হয়নি, তাই অনেকদিন অপে...  Positive
# 12            মালেক আফসারী স্যার এর এক অসাধারণ সৃষ্টি  Positive
# 13                           ইমন এর অভিনয় জাস্ট অসাম🫰  Positive
# 14   এই মুভিটার জন্য  আমি খুব অপেক্ষায়   ছিলাম কবে...  Positive
# 15  যে আমাকে পেলে দ্বিতীয় কাউকে ভাববে না, তার প্রত...  Positive
# 16                             বস শাকিব খান মানে আগুন  Positive
# 17  পুলিশ কে  মেয়ের ছবি  দেখা  তখন আমি  হাসতে  হাস...  Negative
# 18  শাকিব খান,, বুবলি,,  অমিত হাসান,, শিবা শানু,, ...  Positive
# 19  অসাদারণ মুভি শাকিব খান আসল হিরো  ভালোভাবে নিলেননা  Positive

# %%
movie_reviews["comments"][18]
# Out:
# 'শাকিব খান,, বুবলি,,  অমিত হাসান,, শিবা শানু,, ডন ,,, বিশেষ করে ইমনের  এবং ট্যালেন্টেড মিশা সওদাগর সবাই মিলে দারুন একটা মুভি উপহার দিয়েছেন যদিও কাহিনী অনেক কিছু সমস্যা ছিলো তারপরেও অসম্ভব সুন্দর হইছে মুভিটি,,, এগিয়ে যাক শাকিব খানের পাশাপশি সবার বাংলাদেশের ভালো মুভি গুলো।।।।'

# %%
movie_reviews = movie_reviews.dropna(subset=['sentiment'])

# %%
movie_reviews['sentiment'] = movie_reviews['sentiment'].str.strip()

# %%
movie_reviews['sentiment'] = movie_reviews['sentiment'].str.lower()

# %%
print(movie_reviews['sentiment'].unique())
# Out:
# ['positive' 'negative']

# %%
print(movie_reviews['sentiment'].dtype)
# Out:
# object

# %%
movie_reviews['sentiment'] = movie_reviews['sentiment'].astype('category')

# %%
print(movie_reviews['sentiment'].dtype)
# Out:
# category

# %%
# !pip install bangla-stemmer
from bangla_stemmer.stemmer.stemmer import BanglaStemmer
nltk.download('punkt')
# !pip install bangla-stemmer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from imblearn.over_sampling import SMOTE
import nltk
nltk.download('wordnet')
# Out:
# Collecting bangla-stemmer
#   Downloading bangla_stemmer-1.0-py3-none-any.whl (9.1 kB)
# Installing collected packages: bangla-stemmer
# Successfully installed bangla-stemmer-1.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Requirement already satisfied: bangla-stemmer in /usr/local/lib/python3.10/dist-packages (1.0)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import pandas as pd

# Replace the file path with the correct path to your 'stopwords.txt' file
file_path = r'/content/drive/MyDrive/Colab Notebooks/stopwords.txt'
data1 = pd.read_table(file_path)

# %%
print(data1)
stop = data1['words'].tolist()
# Out:
#         words
# 0        অতএব
# 1         অথচ
# 2        অথবা
# 3    অনুযায়ী
# 4        অনেক
# ..        ...
# 393     হাজার
# 394    হিসাবে
# 395      হৈলে
# 396       হোক
# 397        হয়
#
# [398 rows x 1 columns]

# %%
# Define the preprocess_text function
def preprocess_text(text):
    if isinstance(text, str):
        # Convert to lowercase
        text = text.lower()

        # Remove special characters and numbers using regex
        text = re.sub(r"[^A-Za-zঀ-৾]+", ' ', text)

        # Apply stemming using BanglaStemmer
        text = stem_text(text)

        # Tokenize the text and remove custom stopwords
        tokens = nltk.word_tokenize(text)
        tokens = [token for token in tokens if token not in stop]

        # Lemmatize the tokens
        tokens = [lemmatizer.lemmatize(token) for token in tokens]

        # Join tokens back to text
        text = ' '.join(tokens)

        return text
    else:
        return ""  # Return an empty string for non-string inputs

# Function for text stemming
def stem_text(x):
    stemmer = BanglaStemmer()
    words = x.split(' ')
    stm = [stemmer.stem(w) for w in words]
    words = ' '.join(stm)
    return words

# %%
X = movie_reviews['comments'].apply(preprocess_text).tolist()
# Out:
# Streaming output truncated to the last 5000 lines.
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# ...
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied third rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..

# %%
X[18]
# Out:
# 'শাকিব খান বুব অমিত হাসান শিবা শানু ডন ইমন ট্যালেন্টেড মিশা সওদাগর সবা মিলে দারুন এক মুভি উপহ কাহিনী সমস্যা ছিলো তারপরে অসম্ভব সুন্দর হই মুভি এগিয়ে যাক শাকিব খান পাশাপশি বাংলাদেশের ভালো মুভি গুলো'

# %%
y = movie_reviews['sentiment']
y = np.array([ 1 if label == 'positive' else 0 for label in movie_reviews['sentiment']])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from imblearn.over_sampling import SMOTE
from bangla_stemmer.stemmer.stemmer import BanglaStemmer

# %%
# Preprocess X_train and X_test with stopwords removal
X_train_preprocessed = [preprocess_text(comment) for comment in X_train]
X_test_preprocessed = [preprocess_text(comment) for comment in X_test]

# Create and fit the tokenizer
tokenizer = Tokenizer(num_words=5000, oov_token='<UNK>')
tokenizer.fit_on_texts(X_train_preprocessed)

# Get the vocab_size from the tokenizer
vocab_size = len(tokenizer.word_index) + 1

# Convert text data to sequences and pad them
X_train_sequences = tokenizer.texts_to_sequences(X_train_preprocessed)
X_test_sequences = tokenizer.texts_to_sequences(X_test_preprocessed)

maxlen = 1000
X_train_padded = pad_sequences(X_train_sequences, padding='post', maxlen=maxlen)
X_test_padded = pad_sequences(X_test_sequences, padding='post', maxlen=maxlen)

# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_train_padded, y_train = smote.fit_resample(X_train_padded, y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# ...
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..

# %%
import seaborn as sns
import matplotlib.pyplot as plt

order = ["positive", "negative"]
sns.countplot(x='sentiment', data=movie_reviews, order=order)
plt.xlabel('sentiment')
plt.xticks(rotation=45)
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

# Assuming X_train_padded, y_train, X_test_padded, y_test are already prepared

# Convert labels to one-hot encoded format
y_train_one_hot = to_categorical(y_train, num_classes=2)
y_test_one_hot = to_categorical(y_test, num_classes=2)

# Model architecture
embedding_dim = 50
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=maxlen))
model.add(Conv1D(128, 5, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Model training
epochs = 500
batch_size = 32
model.fit(X_train_padded, y_train_one_hot, epochs=epochs, batch_size=batch_size, validation_split=0.2)

# Model evaluation
loss, accuracy = model.evaluate(X_test_padded, y_test_one_hot)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/500
# 456/456 [==============================] - 50s 85ms/step - loss: 0.4250 - accuracy: 0.7897 - val_loss: 0.2797 - val_accuracy: 0.8895
# Epoch 2/500
# 456/456 [==============================] - 20s 44ms/step - loss: 0.2247 - accuracy: 0.9199 - val_loss: 0.2819 - val_accuracy: 0.8890
# Epoch 3/500
# 456/456 [==============================] - 18s 38ms/step - loss: 0.1608 - accuracy: 0.9457 - val_loss: 0.2984 - val_accuracy: 0.9021
# Epoch 4/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.1235 - accuracy: 0.9587 - val_loss: 0.2930 - val_accuracy: 0.8975
# Epoch 5/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0957 - accuracy: 0.9671 - val_loss: 0.3226 - val_accuracy: 0.8925
# Epoch 6/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0817 - accuracy: 0.9741 - val_loss: 0.3235 - val_accuracy: 0.9002
# Epoch 7/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0716 - accuracy: 0.9773 - val_loss: 0.3549 - val_accuracy: 0.8967
# Epoch 8/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0638 - accuracy: 0.9790 - val_loss: 0.3572 - val_accuracy: 0.8978
# Epoch 9/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0565 - accuracy: 0.9820 - val_loss: 0.4552 - val_accuracy: 0.8947
# Epoch 10/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0517 - accuracy: 0.9835 - val_loss: 0.4023 - val_accuracy: 0.8928
# Epoch 11/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0462 - accuracy: 0.9849 - val_loss: 0.4699 - val_accuracy: 0.8947
# Epoch 12/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0465 - accuracy: 0.9849 - val_loss: 0.4809 - val_accuracy: 0.8893
# Epoch 13/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0405 - accuracy: 0.9861 - val_loss: 0.4757 - val_accuracy: 0.8865
# Epoch 14/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0456 - accuracy: 0.9852 - val_loss: 0.5754 - val_accuracy: 0.8882
# Epoch 15/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0394 - accuracy: 0.9866 - val_loss: 0.5431 - val_accuracy: 0.8884
# Epoch 16/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0361 - accuracy: 0.9869 - val_loss: 0.6580 - val_accuracy: 0.8884
# Epoch 17/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0355 - accuracy: 0.9879 - val_loss: 0.5968 - val_accuracy: 0.8931
# Epoch 18/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0365 - accuracy: 0.9881 - val_loss: 0.5743 - val_accuracy: 0.8912
# Epoch 19/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0322 - accuracy: 0.9890 - val_loss: 0.7037 - val_accuracy: 0.8890
# Epoch 20/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0334 - accuracy: 0.9885 - val_loss: 0.7374 - val_accuracy: 0.8862
# Epoch 21/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0312 - accuracy: 0.9897 - val_loss: 0.6709 - val_accuracy: 0.8904
# Epoch 22/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0338 - accuracy: 0.9879 - val_loss: 0.6801 - val_accuracy: 0.8914
# Epoch 23/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0303 - accuracy: 0.9890 - val_loss: 0.6575 - val_accuracy: 0.8868
# Epoch 24/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0311 - accuracy: 0.9893 - val_loss: 0.6688 - val_accuracy: 0.8893
# Epoch 25/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0300 - accuracy: 0.9891 - val_loss: 0.6973 - val_accuracy: 0.8876
# Epoch 26/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0279 - accuracy: 0.9902 - val_loss: 0.6893 - val_accuracy: 0.8849
# Epoch 27/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0261 - accuracy: 0.9904 - val_loss: 0.7527 - val_accuracy: 0.8882
# Epoch 28/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0289 - accuracy: 0.9900 - val_loss: 0.6988 - val_accuracy: 0.8876
# Epoch 29/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0279 - accuracy: 0.9904 - val_loss: 0.6645 - val_accuracy: 0.8909
# Epoch 30/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0264 - accuracy: 0.9904 - val_loss: 0.7796 - val_accuracy: 0.8849
# Epoch 31/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0294 - accuracy: 0.9894 - val_loss: 0.7561 - val_accuracy: 0.8884
# Epoch 32/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0257 - accuracy: 0.9904 - val_loss: 0.8211 - val_accuracy: 0.8917
# Epoch 33/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0244 - accuracy: 0.9910 - val_loss: 0.7718 - val_accuracy: 0.8895
# Epoch 34/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0229 - accuracy: 0.9919 - val_loss: 0.8510 - val_accuracy: 0.8906
# Epoch 35/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0234 - accuracy: 0.9915 - val_loss: 0.8526 - val_accuracy: 0.8909
# Epoch 36/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0252 - accuracy: 0.9912 - val_loss: 0.8347 - val_accuracy: 0.8871
# Epoch 37/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0232 - accuracy: 0.9915 - val_loss: 0.9095 - val_accuracy: 0.8862
# Epoch 38/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0254 - accuracy: 0.9911 - val_loss: 0.8900 - val_accuracy: 0.8890
# Epoch 39/500
# 456/456 [==============================] - 19s 41ms/step - loss: 0.0235 - accuracy: 0.9914 - val_loss: 0.8250 - val_accuracy: 0.8851
# Epoch 40/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0217 - accuracy: 0.9916 - val_loss: 0.9109 - val_accuracy: 0.8868
# Epoch 41/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0229 - accuracy: 0.9914 - val_loss: 0.7365 - val_accuracy: 0.8884
# Epoch 42/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0216 - accuracy: 0.9918 - val_loss: 0.9239 - val_accuracy: 0.8917
# Epoch 43/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.8763 - val_accuracy: 0.8868
# Epoch 44/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0227 - accuracy: 0.9912 - val_loss: 0.9270 - val_accuracy: 0.8862
# Epoch 45/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0213 - accuracy: 0.9919 - val_loss: 0.8691 - val_accuracy: 0.8873
# Epoch 46/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0250 - accuracy: 0.9903 - val_loss: 0.8510 - val_accuracy: 0.8832
# Epoch 47/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0231 - accuracy: 0.9915 - val_loss: 0.8814 - val_accuracy: 0.8865
# Epoch 48/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0220 - accuracy: 0.9918 - val_loss: 0.8713 - val_accuracy: 0.8865
# Epoch 49/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 0.9046 - val_accuracy: 0.8882
# Epoch 50/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0195 - accuracy: 0.9929 - val_loss: 0.8245 - val_accuracy: 0.8901
# Epoch 51/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0193 - accuracy: 0.9932 - val_loss: 0.8320 - val_accuracy: 0.8879
# Epoch 52/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0218 - accuracy: 0.9925 - val_loss: 0.9243 - val_accuracy: 0.8865
# Epoch 53/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0213 - accuracy: 0.9921 - val_loss: 0.9082 - val_accuracy: 0.8879
# Epoch 54/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0222 - accuracy: 0.9923 - val_loss: 0.8727 - val_accuracy: 0.8865
# Epoch 55/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0227 - accuracy: 0.9924 - val_loss: 0.8116 - val_accuracy: 0.8887
# Epoch 56/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0209 - accuracy: 0.9918 - val_loss: 0.7202 - val_accuracy: 0.8884
# Epoch 57/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0195 - accuracy: 0.9932 - val_loss: 0.8230 - val_accuracy: 0.8871
# Epoch 58/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0187 - accuracy: 0.9932 - val_loss: 0.8688 - val_accuracy: 0.8871
# Epoch 59/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0185 - accuracy: 0.9925 - val_loss: 1.0065 - val_accuracy: 0.8887
# Epoch 60/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0196 - accuracy: 0.9926 - val_loss: 0.9389 - val_accuracy: 0.8846
# Epoch 61/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0190 - accuracy: 0.9931 - val_loss: 0.8580 - val_accuracy: 0.8904
# Epoch 62/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0187 - accuracy: 0.9932 - val_loss: 1.0072 - val_accuracy: 0.8895
# Epoch 63/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0185 - accuracy: 0.9926 - val_loss: 1.0035 - val_accuracy: 0.8884
# Epoch 64/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0195 - accuracy: 0.9929 - val_loss: 0.8517 - val_accuracy: 0.8884
# Epoch 65/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0187 - accuracy: 0.9935 - val_loss: 0.9243 - val_accuracy: 0.8862
# Epoch 66/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0197 - accuracy: 0.9925 - val_loss: 0.9602 - val_accuracy: 0.8893
# Epoch 67/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.7843 - val_accuracy: 0.8912
# Epoch 68/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0193 - accuracy: 0.9928 - val_loss: 0.7154 - val_accuracy: 0.8846
# Epoch 69/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0199 - accuracy: 0.9926 - val_loss: 0.8089 - val_accuracy: 0.8873
# Epoch 70/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0189 - accuracy: 0.9929 - val_loss: 0.7805 - val_accuracy: 0.8868
# Epoch 71/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.9613 - val_accuracy: 0.8887
# Epoch 72/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0175 - accuracy: 0.9934 - val_loss: 0.8413 - val_accuracy: 0.8838
# Epoch 73/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0167 - accuracy: 0.9938 - val_loss: 0.9037 - val_accuracy: 0.8868
# Epoch 74/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0184 - accuracy: 0.9929 - val_loss: 0.9291 - val_accuracy: 0.8865
# Epoch 75/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0178 - accuracy: 0.9935 - val_loss: 0.9052 - val_accuracy: 0.8849
# Epoch 76/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0178 - accuracy: 0.9938 - val_loss: 0.8573 - val_accuracy: 0.8835
# Epoch 77/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0188 - accuracy: 0.9930 - val_loss: 0.9746 - val_accuracy: 0.8895
# Epoch 78/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0165 - accuracy: 0.9941 - val_loss: 0.9108 - val_accuracy: 0.8879
# Epoch 79/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0176 - accuracy: 0.9928 - val_loss: 0.9097 - val_accuracy: 0.8876
# Epoch 80/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0177 - accuracy: 0.9930 - val_loss: 0.8768 - val_accuracy: 0.8876
# Epoch 81/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0187 - accuracy: 0.9927 - val_loss: 0.7506 - val_accuracy: 0.8854
# Epoch 82/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0180 - accuracy: 0.9934 - val_loss: 0.9533 - val_accuracy: 0.8862
# Epoch 83/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0180 - accuracy: 0.9932 - val_loss: 0.8124 - val_accuracy: 0.8873
# Epoch 84/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0161 - accuracy: 0.9945 - val_loss: 0.9821 - val_accuracy: 0.8879
# Epoch 85/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0162 - accuracy: 0.9931 - val_loss: 1.0454 - val_accuracy: 0.8906
# Epoch 86/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0171 - accuracy: 0.9936 - val_loss: 0.9652 - val_accuracy: 0.8876
# Epoch 87/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0168 - accuracy: 0.9937 - val_loss: 0.9034 - val_accuracy: 0.8876
# Epoch 88/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0165 - accuracy: 0.9929 - val_loss: 0.9416 - val_accuracy: 0.8879
# Epoch 89/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0170 - accuracy: 0.9941 - val_loss: 0.9170 - val_accuracy: 0.8865
# Epoch 90/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0161 - accuracy: 0.9940 - val_loss: 1.0956 - val_accuracy: 0.8873
# Epoch 91/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0172 - accuracy: 0.9937 - val_loss: 0.8907 - val_accuracy: 0.8862
# Epoch 92/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0207 - accuracy: 0.9915 - val_loss: 0.8549 - val_accuracy: 0.8838
# Epoch 93/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0187 - accuracy: 0.9928 - val_loss: 0.8580 - val_accuracy: 0.8838
# Epoch 94/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0163 - accuracy: 0.9937 - val_loss: 0.9953 - val_accuracy: 0.8868
# Epoch 95/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0185 - accuracy: 0.9933 - val_loss: 0.9692 - val_accuracy: 0.8851
# Epoch 96/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.8674 - val_accuracy: 0.8840
# Epoch 97/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0172 - accuracy: 0.9936 - val_loss: 0.8106 - val_accuracy: 0.8860
# Epoch 98/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0141 - accuracy: 0.9942 - val_loss: 1.1038 - val_accuracy: 0.8860
# Epoch 99/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0159 - accuracy: 0.9933 - val_loss: 1.0723 - val_accuracy: 0.8854
# Epoch 100/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0169 - accuracy: 0.9934 - val_loss: 0.8544 - val_accuracy: 0.8854
# Epoch 101/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0165 - accuracy: 0.9938 - val_loss: 1.0785 - val_accuracy: 0.8851
# Epoch 102/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0165 - accuracy: 0.9934 - val_loss: 0.9747 - val_accuracy: 0.8871
# Epoch 103/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0164 - accuracy: 0.9934 - val_loss: 1.1589 - val_accuracy: 0.8876
# Epoch 104/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0167 - accuracy: 0.9942 - val_loss: 0.8718 - val_accuracy: 0.8887
# Epoch 105/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0179 - accuracy: 0.9936 - val_loss: 0.8207 - val_accuracy: 0.8865
# Epoch 106/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0160 - accuracy: 0.9936 - val_loss: 0.9277 - val_accuracy: 0.8862
# Epoch 107/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0162 - accuracy: 0.9941 - val_loss: 0.7861 - val_accuracy: 0.8851
# Epoch 108/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 1.0533 - val_accuracy: 0.8832
# Epoch 109/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0152 - accuracy: 0.9944 - val_loss: 1.1157 - val_accuracy: 0.8871
# Epoch 110/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0164 - accuracy: 0.9939 - val_loss: 0.9318 - val_accuracy: 0.8832
# Epoch 111/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0166 - accuracy: 0.9938 - val_loss: 0.9459 - val_accuracy: 0.8824
# Epoch 112/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0176 - accuracy: 0.9932 - val_loss: 0.9862 - val_accuracy: 0.8816
# Epoch 113/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 1.0955 - val_accuracy: 0.8840
# Epoch 114/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0160 - accuracy: 0.9938 - val_loss: 1.0883 - val_accuracy: 0.8838
# Epoch 115/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 1.0509 - val_accuracy: 0.8865
# Epoch 116/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 0.8984 - val_accuracy: 0.8857
# Epoch 117/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0160 - accuracy: 0.9942 - val_loss: 0.8744 - val_accuracy: 0.8843
# Epoch 118/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0161 - accuracy: 0.9938 - val_loss: 0.9998 - val_accuracy: 0.8860
# Epoch 119/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.9674 - val_accuracy: 0.8876
# Epoch 120/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0166 - accuracy: 0.9938 - val_loss: 0.9328 - val_accuracy: 0.8862
# Epoch 121/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0163 - accuracy: 0.9934 - val_loss: 0.9631 - val_accuracy: 0.8884
# Epoch 122/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0173 - accuracy: 0.9934 - val_loss: 1.0679 - val_accuracy: 0.8829
# Epoch 123/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 1.1200 - val_accuracy: 0.8860
# Epoch 124/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 0.9630 - val_accuracy: 0.8840
# Epoch 125/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 1.0070 - val_accuracy: 0.8854
# Epoch 126/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0151 - accuracy: 0.9943 - val_loss: 1.0778 - val_accuracy: 0.8871
# Epoch 127/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0176 - accuracy: 0.9933 - val_loss: 0.9003 - val_accuracy: 0.8882
# Epoch 128/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0151 - accuracy: 0.9940 - val_loss: 1.1666 - val_accuracy: 0.8879
# Epoch 129/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0140 - accuracy: 0.9942 - val_loss: 1.1288 - val_accuracy: 0.8871
# Epoch 130/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0159 - accuracy: 0.9942 - val_loss: 1.0359 - val_accuracy: 0.8854
# Epoch 131/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0164 - accuracy: 0.9940 - val_loss: 0.9245 - val_accuracy: 0.8868
# Epoch 132/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0152 - accuracy: 0.9945 - val_loss: 1.0049 - val_accuracy: 0.8835
# Epoch 133/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0152 - accuracy: 0.9942 - val_loss: 1.0974 - val_accuracy: 0.8843
# Epoch 134/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0168 - accuracy: 0.9939 - val_loss: 1.0214 - val_accuracy: 0.8838
# Epoch 135/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0174 - accuracy: 0.9931 - val_loss: 0.8451 - val_accuracy: 0.8884
# Epoch 136/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9941 - val_loss: 0.8987 - val_accuracy: 0.8827
# Epoch 137/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0139 - accuracy: 0.9947 - val_loss: 0.9364 - val_accuracy: 0.8851
# Epoch 138/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0155 - accuracy: 0.9942 - val_loss: 1.0099 - val_accuracy: 0.8862
# Epoch 139/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0157 - accuracy: 0.9938 - val_loss: 1.0666 - val_accuracy: 0.8843
# Epoch 140/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0147 - accuracy: 0.9938 - val_loss: 1.1625 - val_accuracy: 0.8816
# Epoch 141/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0156 - accuracy: 0.9937 - val_loss: 1.0775 - val_accuracy: 0.8819
# Epoch 142/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0151 - accuracy: 0.9940 - val_loss: 0.9903 - val_accuracy: 0.8851
# Epoch 143/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0149 - accuracy: 0.9942 - val_loss: 1.2194 - val_accuracy: 0.8813
# Epoch 144/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0142 - accuracy: 0.9940 - val_loss: 0.9259 - val_accuracy: 0.8819
# Epoch 145/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 1.0534 - val_accuracy: 0.8786
# Epoch 146/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 1.0538 - val_accuracy: 0.8849
# Epoch 147/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.9128 - val_accuracy: 0.8829
# Epoch 148/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0138 - accuracy: 0.9941 - val_loss: 1.1305 - val_accuracy: 0.8846
# Epoch 149/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0147 - accuracy: 0.9942 - val_loss: 1.1135 - val_accuracy: 0.8846
# Epoch 150/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0163 - accuracy: 0.9934 - val_loss: 0.8366 - val_accuracy: 0.8843
# Epoch 151/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0162 - accuracy: 0.9933 - val_loss: 0.9325 - val_accuracy: 0.8824
# Epoch 152/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0141 - accuracy: 0.9938 - val_loss: 1.2361 - val_accuracy: 0.8865
# Epoch 153/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 1.1167 - val_accuracy: 0.8843
# Epoch 154/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0138 - accuracy: 0.9946 - val_loss: 1.3651 - val_accuracy: 0.8846
# Epoch 155/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0145 - accuracy: 0.9942 - val_loss: 1.0823 - val_accuracy: 0.8805
# Epoch 156/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0152 - accuracy: 0.9934 - val_loss: 1.1964 - val_accuracy: 0.8827
# Epoch 157/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0148 - accuracy: 0.9941 - val_loss: 1.0624 - val_accuracy: 0.8832
# Epoch 158/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0153 - accuracy: 0.9940 - val_loss: 1.0516 - val_accuracy: 0.8827
# Epoch 159/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 1.1521 - val_accuracy: 0.8860
# Epoch 160/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.9065 - val_accuracy: 0.8838
# Epoch 161/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0163 - accuracy: 0.9935 - val_loss: 0.9708 - val_accuracy: 0.8827
# Epoch 162/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0147 - accuracy: 0.9940 - val_loss: 1.0639 - val_accuracy: 0.8843
# Epoch 163/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0139 - accuracy: 0.9946 - val_loss: 1.0950 - val_accuracy: 0.8810
# Epoch 164/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0150 - accuracy: 0.9942 - val_loss: 1.1562 - val_accuracy: 0.8794
# Epoch 165/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0151 - accuracy: 0.9937 - val_loss: 1.2119 - val_accuracy: 0.8824
# Epoch 166/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0157 - accuracy: 0.9942 - val_loss: 0.9639 - val_accuracy: 0.8819
# Epoch 167/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0146 - accuracy: 0.9944 - val_loss: 1.0284 - val_accuracy: 0.8810
# Epoch 168/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9937 - val_loss: 1.1580 - val_accuracy: 0.8821
# Epoch 169/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0153 - accuracy: 0.9938 - val_loss: 0.9307 - val_accuracy: 0.8824
# Epoch 170/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0151 - accuracy: 0.9938 - val_loss: 1.0434 - val_accuracy: 0.8873
# Epoch 171/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0148 - accuracy: 0.9942 - val_loss: 1.1337 - val_accuracy: 0.8835
# Epoch 172/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0167 - accuracy: 0.9940 - val_loss: 0.8357 - val_accuracy: 0.8849
# Epoch 173/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 1.0099 - val_accuracy: 0.8819
# Epoch 174/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.7675 - val_accuracy: 0.8805
# Epoch 175/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0134 - accuracy: 0.9944 - val_loss: 1.2960 - val_accuracy: 0.8829
# Epoch 176/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0151 - accuracy: 0.9941 - val_loss: 1.0283 - val_accuracy: 0.8846
# Epoch 177/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0149 - accuracy: 0.9944 - val_loss: 1.0574 - val_accuracy: 0.8816
# Epoch 178/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0150 - accuracy: 0.9939 - val_loss: 1.1496 - val_accuracy: 0.8813
# Epoch 179/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0145 - accuracy: 0.9939 - val_loss: 1.1910 - val_accuracy: 0.8813
# Epoch 180/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0156 - accuracy: 0.9947 - val_loss: 1.0265 - val_accuracy: 0.8819
# Epoch 181/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9942 - val_loss: 1.0834 - val_accuracy: 0.8832
# Epoch 182/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0158 - accuracy: 0.9943 - val_loss: 1.0195 - val_accuracy: 0.8838
# Epoch 183/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0143 - accuracy: 0.9942 - val_loss: 1.0973 - val_accuracy: 0.8835
# Epoch 184/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 1.1276 - val_accuracy: 0.8797
# Epoch 185/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0147 - accuracy: 0.9944 - val_loss: 0.9929 - val_accuracy: 0.8808
# Epoch 186/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0142 - accuracy: 0.9944 - val_loss: 1.0175 - val_accuracy: 0.8791
# Epoch 187/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0142 - accuracy: 0.9947 - val_loss: 1.0498 - val_accuracy: 0.8835
# Epoch 188/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9942 - val_loss: 1.1007 - val_accuracy: 0.8838
# Epoch 189/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 1.1058 - val_accuracy: 0.8829
# Epoch 190/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0149 - accuracy: 0.9941 - val_loss: 0.9578 - val_accuracy: 0.8851
# Epoch 191/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 1.1438 - val_accuracy: 0.8819
# Epoch 192/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9934 - val_loss: 1.2937 - val_accuracy: 0.8827
# Epoch 193/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0145 - accuracy: 0.9949 - val_loss: 1.1596 - val_accuracy: 0.8824
# Epoch 194/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0153 - accuracy: 0.9944 - val_loss: 1.2325 - val_accuracy: 0.8821
# Epoch 195/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0138 - accuracy: 0.9944 - val_loss: 1.1954 - val_accuracy: 0.8827
# Epoch 196/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0139 - accuracy: 0.9945 - val_loss: 1.3670 - val_accuracy: 0.8838
# Epoch 197/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0143 - accuracy: 0.9942 - val_loss: 1.0398 - val_accuracy: 0.8819
# Epoch 198/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 1.0836 - val_accuracy: 0.8838
# Epoch 199/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0143 - accuracy: 0.9943 - val_loss: 1.1310 - val_accuracy: 0.8838
# Epoch 200/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0123 - accuracy: 0.9951 - val_loss: 1.4841 - val_accuracy: 0.8854
# Epoch 201/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0142 - accuracy: 0.9949 - val_loss: 1.2505 - val_accuracy: 0.8849
# Epoch 202/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0160 - accuracy: 0.9942 - val_loss: 1.0369 - val_accuracy: 0.8829
# Epoch 203/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0154 - accuracy: 0.9942 - val_loss: 1.2468 - val_accuracy: 0.8824
# Epoch 204/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0140 - accuracy: 0.9944 - val_loss: 1.3577 - val_accuracy: 0.8838
# Epoch 205/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0138 - accuracy: 0.9943 - val_loss: 1.3024 - val_accuracy: 0.8843
# Epoch 206/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0148 - accuracy: 0.9945 - val_loss: 1.0410 - val_accuracy: 0.8829
# Epoch 207/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0128 - accuracy: 0.9947 - val_loss: 1.2801 - val_accuracy: 0.8829
# Epoch 208/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0145 - accuracy: 0.9939 - val_loss: 1.2271 - val_accuracy: 0.8829
# Epoch 209/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0159 - accuracy: 0.9940 - val_loss: 1.0185 - val_accuracy: 0.8824
# Epoch 210/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0131 - accuracy: 0.9946 - val_loss: 1.1896 - val_accuracy: 0.8829
# Epoch 211/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0134 - accuracy: 0.9946 - val_loss: 1.2769 - val_accuracy: 0.8821
# Epoch 212/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 1.0993 - val_accuracy: 0.8835
# Epoch 213/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0147 - accuracy: 0.9945 - val_loss: 1.0852 - val_accuracy: 0.8843
# Epoch 214/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0134 - accuracy: 0.9945 - val_loss: 1.1821 - val_accuracy: 0.8838
# Epoch 215/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0139 - accuracy: 0.9947 - val_loss: 1.2009 - val_accuracy: 0.8838
# Epoch 216/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0150 - accuracy: 0.9940 - val_loss: 1.2531 - val_accuracy: 0.8810
# Epoch 217/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0138 - accuracy: 0.9943 - val_loss: 1.2447 - val_accuracy: 0.8835
# Epoch 218/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0128 - accuracy: 0.9949 - val_loss: 1.4924 - val_accuracy: 0.8808
# Epoch 219/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0129 - accuracy: 0.9948 - val_loss: 1.2317 - val_accuracy: 0.8819
# Epoch 220/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0128 - accuracy: 0.9947 - val_loss: 1.4608 - val_accuracy: 0.8802
# Epoch 221/500
# 456/456 [==============================] - 16s 34ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 1.3046 - val_accuracy: 0.8824
# Epoch 222/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0144 - accuracy: 0.9941 - val_loss: 1.3749 - val_accuracy: 0.8808
# Epoch 223/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0154 - accuracy: 0.9941 - val_loss: 1.0572 - val_accuracy: 0.8816
# Epoch 224/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0145 - accuracy: 0.9937 - val_loss: 1.1737 - val_accuracy: 0.8829
# Epoch 225/500
# 456/456 [==============================] - 19s 41ms/step - loss: 0.0167 - accuracy: 0.9939 - val_loss: 0.9166 - val_accuracy: 0.8840
# Epoch 226/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0168 - accuracy: 0.9942 - val_loss: 0.9970 - val_accuracy: 0.8819
# Epoch 227/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0136 - accuracy: 0.9946 - val_loss: 1.0515 - val_accuracy: 0.8827
# Epoch 228/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9940 - val_loss: 0.9485 - val_accuracy: 0.8843
# Epoch 229/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0140 - accuracy: 0.9945 - val_loss: 1.0799 - val_accuracy: 0.8871
# Epoch 230/500
# 456/456 [==============================] - 18s 38ms/step - loss: 0.0138 - accuracy: 0.9947 - val_loss: 0.9152 - val_accuracy: 0.8862
# Epoch 231/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0137 - accuracy: 0.9943 - val_loss: 1.0295 - val_accuracy: 0.8854
# Epoch 232/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9942 - val_loss: 1.1809 - val_accuracy: 0.8832
# Epoch 233/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0141 - accuracy: 0.9948 - val_loss: 1.1579 - val_accuracy: 0.8857
# Epoch 234/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0140 - accuracy: 0.9944 - val_loss: 1.1148 - val_accuracy: 0.8854
# Epoch 235/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0135 - accuracy: 0.9945 - val_loss: 1.2395 - val_accuracy: 0.8846
# Epoch 236/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0150 - accuracy: 0.9942 - val_loss: 1.1385 - val_accuracy: 0.8840
# Epoch 237/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0138 - accuracy: 0.9941 - val_loss: 1.4277 - val_accuracy: 0.8862
# Epoch 238/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0151 - accuracy: 0.9940 - val_loss: 1.2047 - val_accuracy: 0.8873
# Epoch 239/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0140 - accuracy: 0.9946 - val_loss: 1.1539 - val_accuracy: 0.8832
# Epoch 240/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0151 - accuracy: 0.9939 - val_loss: 1.0715 - val_accuracy: 0.8882
# Epoch 241/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 1.1169 - val_accuracy: 0.8884
# Epoch 242/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0145 - accuracy: 0.9943 - val_loss: 1.1432 - val_accuracy: 0.8860
# Epoch 243/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0138 - accuracy: 0.9942 - val_loss: 1.1950 - val_accuracy: 0.8884
# Epoch 244/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 1.1015 - val_accuracy: 0.8857
# Epoch 245/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0135 - accuracy: 0.9940 - val_loss: 1.2339 - val_accuracy: 0.8865
# Epoch 246/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0137 - accuracy: 0.9946 - val_loss: 1.2712 - val_accuracy: 0.8876
# Epoch 247/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0129 - accuracy: 0.9948 - val_loss: 1.2875 - val_accuracy: 0.8901
# Epoch 248/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0153 - accuracy: 0.9942 - val_loss: 0.9018 - val_accuracy: 0.8887
# Epoch 249/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0141 - accuracy: 0.9944 - val_loss: 1.0931 - val_accuracy: 0.8882
# Epoch 250/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0130 - accuracy: 0.9944 - val_loss: 1.3204 - val_accuracy: 0.8873
# Epoch 251/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0138 - accuracy: 0.9944 - val_loss: 1.4190 - val_accuracy: 0.8879
# Epoch 252/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 1.0494 - val_accuracy: 0.8901
# Epoch 253/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0145 - accuracy: 0.9942 - val_loss: 1.2845 - val_accuracy: 0.8890
# Epoch 254/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 1.0988 - val_accuracy: 0.8890
# Epoch 255/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0125 - accuracy: 0.9951 - val_loss: 1.1921 - val_accuracy: 0.8865
# Epoch 256/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0146 - accuracy: 0.9948 - val_loss: 1.2393 - val_accuracy: 0.8865
# Epoch 257/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0125 - accuracy: 0.9949 - val_loss: 1.3223 - val_accuracy: 0.8887
# Epoch 258/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0138 - accuracy: 0.9944 - val_loss: 1.2301 - val_accuracy: 0.8873
# Epoch 259/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0131 - accuracy: 0.9944 - val_loss: 1.4895 - val_accuracy: 0.8871
# Epoch 260/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0128 - accuracy: 0.9947 - val_loss: 1.3006 - val_accuracy: 0.8873
# Epoch 261/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0146 - accuracy: 0.9947 - val_loss: 1.2276 - val_accuracy: 0.8873
# Epoch 262/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0114 - accuracy: 0.9949 - val_loss: 1.3154 - val_accuracy: 0.8862
# Epoch 263/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 1.2686 - val_accuracy: 0.8862
# Epoch 264/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0143 - accuracy: 0.9944 - val_loss: 1.2846 - val_accuracy: 0.8846
# Epoch 265/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0149 - accuracy: 0.9947 - val_loss: 1.1983 - val_accuracy: 0.8865
# Epoch 266/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0145 - accuracy: 0.9944 - val_loss: 0.9254 - val_accuracy: 0.8871
# Epoch 267/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0138 - accuracy: 0.9940 - val_loss: 1.2748 - val_accuracy: 0.8851
# Epoch 268/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0141 - accuracy: 0.9945 - val_loss: 1.2077 - val_accuracy: 0.8862
# Epoch 269/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0134 - accuracy: 0.9946 - val_loss: 1.2700 - val_accuracy: 0.8824
# Epoch 270/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0147 - accuracy: 0.9943 - val_loss: 1.1737 - val_accuracy: 0.8857
# Epoch 271/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0139 - accuracy: 0.9947 - val_loss: 1.2008 - val_accuracy: 0.8838
# Epoch 272/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0133 - accuracy: 0.9943 - val_loss: 1.2360 - val_accuracy: 0.8851
# Epoch 273/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0147 - accuracy: 0.9940 - val_loss: 0.9219 - val_accuracy: 0.8851
# Epoch 274/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0154 - accuracy: 0.9944 - val_loss: 1.0890 - val_accuracy: 0.8862
# Epoch 275/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0132 - accuracy: 0.9943 - val_loss: 1.2280 - val_accuracy: 0.8857
# Epoch 276/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0131 - accuracy: 0.9944 - val_loss: 1.2061 - val_accuracy: 0.8860
# Epoch 277/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0135 - accuracy: 0.9943 - val_loss: 1.3853 - val_accuracy: 0.8865
# Epoch 278/500
# 456/456 [==============================] - 18s 41ms/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 1.3056 - val_accuracy: 0.8871
# Epoch 279/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 1.1306 - val_accuracy: 0.8887
# Epoch 280/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0139 - accuracy: 0.9946 - val_loss: 0.9992 - val_accuracy: 0.8862
# Epoch 281/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0142 - accuracy: 0.9942 - val_loss: 1.0347 - val_accuracy: 0.8854
# Epoch 282/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 1.0482 - val_accuracy: 0.8840
# Epoch 283/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0153 - accuracy: 0.9941 - val_loss: 1.0225 - val_accuracy: 0.8860
# Epoch 284/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0139 - accuracy: 0.9949 - val_loss: 0.9482 - val_accuracy: 0.8868
# Epoch 285/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0153 - accuracy: 0.9943 - val_loss: 1.0555 - val_accuracy: 0.8873
# Epoch 286/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0127 - accuracy: 0.9949 - val_loss: 1.3896 - val_accuracy: 0.8838
# Epoch 287/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 1.3218 - val_accuracy: 0.8865
# Epoch 288/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0125 - accuracy: 0.9951 - val_loss: 1.3980 - val_accuracy: 0.8851
# Epoch 289/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 1.1045 - val_accuracy: 0.8854
# Epoch 290/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0135 - accuracy: 0.9942 - val_loss: 1.3302 - val_accuracy: 0.8884
# Epoch 291/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0119 - accuracy: 0.9950 - val_loss: 1.4295 - val_accuracy: 0.8873
# Epoch 292/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0170 - accuracy: 0.9949 - val_loss: 0.9465 - val_accuracy: 0.8862
# Epoch 293/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0145 - accuracy: 0.9942 - val_loss: 1.1429 - val_accuracy: 0.8857
# Epoch 294/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0173 - accuracy: 0.9933 - val_loss: 0.9746 - val_accuracy: 0.8849
# Epoch 295/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.8428 - val_accuracy: 0.8843
# Epoch 296/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0157 - accuracy: 0.9940 - val_loss: 0.9901 - val_accuracy: 0.8854
# Epoch 297/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0163 - accuracy: 0.9942 - val_loss: 0.8751 - val_accuracy: 0.8860
# Epoch 298/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0127 - accuracy: 0.9948 - val_loss: 1.1242 - val_accuracy: 0.8840
# Epoch 299/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0133 - accuracy: 0.9941 - val_loss: 1.0675 - val_accuracy: 0.8835
# Epoch 300/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0136 - accuracy: 0.9948 - val_loss: 1.0646 - val_accuracy: 0.8890
# Epoch 301/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0126 - accuracy: 0.9947 - val_loss: 1.1573 - val_accuracy: 0.8854
# Epoch 302/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0127 - accuracy: 0.9947 - val_loss: 1.1688 - val_accuracy: 0.8849
# Epoch 303/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 1.1800 - val_accuracy: 0.8846
# Epoch 304/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0140 - accuracy: 0.9943 - val_loss: 1.2399 - val_accuracy: 0.8840
# Epoch 305/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0129 - accuracy: 0.9947 - val_loss: 1.3619 - val_accuracy: 0.8838
# Epoch 306/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0132 - accuracy: 0.9944 - val_loss: 1.2149 - val_accuracy: 0.8860
# Epoch 307/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0144 - accuracy: 0.9944 - val_loss: 1.0551 - val_accuracy: 0.8838
# Epoch 308/500
# 456/456 [==============================] - 18s 38ms/step - loss: 0.0124 - accuracy: 0.9951 - val_loss: 1.2261 - val_accuracy: 0.8835
# Epoch 309/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0139 - accuracy: 0.9944 - val_loss: 1.3678 - val_accuracy: 0.8819
# Epoch 310/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0151 - accuracy: 0.9944 - val_loss: 1.0657 - val_accuracy: 0.8827
# Epoch 311/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0136 - accuracy: 0.9946 - val_loss: 1.2596 - val_accuracy: 0.8838
# Epoch 312/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 1.2569 - val_accuracy: 0.8862
# Epoch 313/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0134 - accuracy: 0.9949 - val_loss: 1.0902 - val_accuracy: 0.8857
# Epoch 314/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0128 - accuracy: 0.9945 - val_loss: 1.0693 - val_accuracy: 0.8851
# Epoch 315/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0151 - accuracy: 0.9945 - val_loss: 1.1429 - val_accuracy: 0.8862
# Epoch 316/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 0.9467 - val_accuracy: 0.8871
# Epoch 317/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0129 - accuracy: 0.9949 - val_loss: 1.0792 - val_accuracy: 0.8857
# Epoch 318/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0156 - accuracy: 0.9942 - val_loss: 1.0418 - val_accuracy: 0.8865
# Epoch 319/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0272 - accuracy: 0.9914 - val_loss: 0.7425 - val_accuracy: 0.8854
# Epoch 320/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0318 - accuracy: 0.9881 - val_loss: 0.7819 - val_accuracy: 0.8857
# Epoch 321/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0322 - accuracy: 0.9889 - val_loss: 0.7164 - val_accuracy: 0.8882
# Epoch 322/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0322 - accuracy: 0.9880 - val_loss: 0.8243 - val_accuracy: 0.8846
# Epoch 323/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0285 - accuracy: 0.9881 - val_loss: 0.8259 - val_accuracy: 0.8860
# Epoch 324/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0301 - accuracy: 0.9889 - val_loss: 0.7749 - val_accuracy: 0.8865
# Epoch 325/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0303 - accuracy: 0.9886 - val_loss: 0.7232 - val_accuracy: 0.8879
# Epoch 326/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0283 - accuracy: 0.9885 - val_loss: 0.7096 - val_accuracy: 0.8835
# Epoch 327/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0302 - accuracy: 0.9888 - val_loss: 0.7547 - val_accuracy: 0.8873
# Epoch 328/500
# ...
# Epoch 394/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0147 - accuracy: 0.9944 - val_loss: 1.1730 - val_accuracy: 0.8840
# Epoch 395/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0158 - accuracy: 0.9942 - val_loss: 1.2308 - val_accuracy: 0.8854
# Epoch 396/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0154 - accuracy: 0.9944 - val_loss: 0.9737 - val_accuracy: 0.8857
# Epoch 397/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0140 - accuracy: 0.9949 - val_loss: 0.9759 - val_accuracy: 0.8849
# Epoch 398/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0149 - accuracy: 0.9944 - val_loss: 0.9615 - val_accuracy: 0.8849
# Epoch 399/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0143 - accuracy: 0.9946 - val_loss: 1.2779 - val_accuracy: 0.8843
# Epoch 400/500
# 456/456 [==============================] - 18s 38ms/step - loss: 0.0162 - accuracy: 0.9947 - val_loss: 1.0339 - val_accuracy: 0.8838
# Epoch 401/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0134 - accuracy: 0.9946 - val_loss: 1.2590 - val_accuracy: 0.8857
# Epoch 402/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0143 - accuracy: 0.9945 - val_loss: 0.9875 - val_accuracy: 0.8862
# Epoch 403/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0128 - accuracy: 0.9951 - val_loss: 1.2934 - val_accuracy: 0.8846
# Epoch 404/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0148 - accuracy: 0.9949 - val_loss: 1.1568 - val_accuracy: 0.8838
# Epoch 405/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0160 - accuracy: 0.9942 - val_loss: 0.8760 - val_accuracy: 0.8832
# Epoch 406/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0135 - accuracy: 0.9951 - val_loss: 1.0705 - val_accuracy: 0.8835
# Epoch 407/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 1.0072 - val_accuracy: 0.8838
# Epoch 408/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0133 - accuracy: 0.9951 - val_loss: 1.1023 - val_accuracy: 0.8840
# Epoch 409/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0127 - accuracy: 0.9947 - val_loss: 1.2275 - val_accuracy: 0.8849
# Epoch 410/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0134 - accuracy: 0.9946 - val_loss: 1.3376 - val_accuracy: 0.8857
# Epoch 411/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0144 - accuracy: 0.9946 - val_loss: 1.1369 - val_accuracy: 0.8843
# Epoch 412/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 1.2942 - val_accuracy: 0.8838
# Epoch 413/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0153 - accuracy: 0.9942 - val_loss: 1.1557 - val_accuracy: 0.8851
# Epoch 414/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 1.1991 - val_accuracy: 0.8849
# Epoch 415/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0151 - accuracy: 0.9943 - val_loss: 1.0961 - val_accuracy: 0.8843
# Epoch 416/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0133 - accuracy: 0.9942 - val_loss: 1.2083 - val_accuracy: 0.8843
# Epoch 417/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0137 - accuracy: 0.9949 - val_loss: 1.2821 - val_accuracy: 0.8835
# Epoch 418/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.9994 - val_accuracy: 0.8827
# Epoch 419/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 1.0781 - val_accuracy: 0.8821
# Epoch 420/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 1.0512 - val_accuracy: 0.8832
# Epoch 421/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0151 - accuracy: 0.9941 - val_loss: 0.8682 - val_accuracy: 0.8810
# Epoch 422/500
# 456/456 [==============================] - 16s 35ms/step - loss: 0.0150 - accuracy: 0.9942 - val_loss: 0.9793 - val_accuracy: 0.8840
# Epoch 423/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0132 - accuracy: 0.9949 - val_loss: 0.9489 - val_accuracy: 0.8824
# Epoch 424/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0162 - accuracy: 0.9940 - val_loss: 0.7974 - val_accuracy: 0.8846
# Epoch 425/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 1.0993 - val_accuracy: 0.8835
# Epoch 426/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 1.0899 - val_accuracy: 0.8827
# Epoch 427/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0126 - accuracy: 0.9947 - val_loss: 1.0723 - val_accuracy: 0.8835
# Epoch 428/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0153 - accuracy: 0.9941 - val_loss: 0.9360 - val_accuracy: 0.8857
# Epoch 429/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0122 - accuracy: 0.9949 - val_loss: 1.1182 - val_accuracy: 0.8851
# Epoch 430/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0142 - accuracy: 0.9944 - val_loss: 1.0663 - val_accuracy: 0.8846
# Epoch 431/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0125 - accuracy: 0.9948 - val_loss: 1.0987 - val_accuracy: 0.8849
# Epoch 432/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0136 - accuracy: 0.9949 - val_loss: 1.1536 - val_accuracy: 0.8843
# Epoch 433/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0167 - accuracy: 0.9947 - val_loss: 0.9918 - val_accuracy: 0.8838
# Epoch 434/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0140 - accuracy: 0.9949 - val_loss: 1.0029 - val_accuracy: 0.8835
# Epoch 435/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.9682 - val_accuracy: 0.8821
# Epoch 436/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 1.0144 - val_accuracy: 0.8835
# Epoch 437/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.8274 - val_accuracy: 0.8846
# Epoch 438/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0148 - accuracy: 0.9944 - val_loss: 0.8666 - val_accuracy: 0.8838
# Epoch 439/500
# 456/456 [==============================] - 18s 40ms/step - loss: 0.0139 - accuracy: 0.9946 - val_loss: 0.9180 - val_accuracy: 0.8840
# Epoch 440/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0142 - accuracy: 0.9944 - val_loss: 0.9862 - val_accuracy: 0.8849
# Epoch 441/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0137 - accuracy: 0.9946 - val_loss: 1.0366 - val_accuracy: 0.8843
# Epoch 442/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 0.8831 - val_accuracy: 0.8854
# Epoch 443/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0138 - accuracy: 0.9946 - val_loss: 1.0114 - val_accuracy: 0.8857
# Epoch 444/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 0.9822 - val_accuracy: 0.8849
# Epoch 445/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 1.0341 - val_accuracy: 0.8843
# Epoch 446/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0139 - accuracy: 0.9947 - val_loss: 1.0896 - val_accuracy: 0.8832
# Epoch 447/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0142 - accuracy: 0.9949 - val_loss: 0.9491 - val_accuracy: 0.8843
# Epoch 448/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.9955 - val_accuracy: 0.8849
# Epoch 449/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0130 - accuracy: 0.9949 - val_loss: 1.2631 - val_accuracy: 0.8846
# Epoch 450/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0142 - accuracy: 0.9945 - val_loss: 1.0613 - val_accuracy: 0.8835
# Epoch 451/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0129 - accuracy: 0.9950 - val_loss: 1.2164 - val_accuracy: 0.8838
# Epoch 452/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 1.3667 - val_accuracy: 0.8849
# Epoch 453/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0130 - accuracy: 0.9947 - val_loss: 1.2260 - val_accuracy: 0.8821
# Epoch 454/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0146 - accuracy: 0.9944 - val_loss: 1.2922 - val_accuracy: 0.8799
# Epoch 455/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 1.1538 - val_accuracy: 0.8821
# Epoch 456/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0129 - accuracy: 0.9948 - val_loss: 1.2659 - val_accuracy: 0.8843
# Epoch 457/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 1.2885 - val_accuracy: 0.8857
# Epoch 458/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0134 - accuracy: 0.9947 - val_loss: 1.2833 - val_accuracy: 0.8846
# Epoch 459/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0152 - accuracy: 0.9940 - val_loss: 1.1355 - val_accuracy: 0.8840
# Epoch 460/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 1.1152 - val_accuracy: 0.8846
# Epoch 461/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0128 - accuracy: 0.9951 - val_loss: 1.3057 - val_accuracy: 0.8846
# Epoch 462/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 1.1099 - val_accuracy: 0.8862
# Epoch 463/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0145 - accuracy: 0.9945 - val_loss: 1.0913 - val_accuracy: 0.8857
# Epoch 464/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0128 - accuracy: 0.9950 - val_loss: 1.3506 - val_accuracy: 0.8829
# Epoch 465/500
# 456/456 [==============================] - 18s 40ms/step - loss: 0.0143 - accuracy: 0.9944 - val_loss: 1.3542 - val_accuracy: 0.8821
# Epoch 466/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0151 - accuracy: 0.9948 - val_loss: 1.0308 - val_accuracy: 0.8840
# Epoch 467/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0145 - accuracy: 0.9946 - val_loss: 0.7628 - val_accuracy: 0.8851
# Epoch 468/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 1.0078 - val_accuracy: 0.8860
# Epoch 469/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0150 - accuracy: 0.9942 - val_loss: 1.2469 - val_accuracy: 0.8857
# Epoch 470/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.9037 - val_accuracy: 0.8871
# Epoch 471/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0135 - accuracy: 0.9947 - val_loss: 0.9648 - val_accuracy: 0.8846
# Epoch 472/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0141 - accuracy: 0.9947 - val_loss: 1.0979 - val_accuracy: 0.8832
# Epoch 473/500
# 456/456 [==============================] - 17s 38ms/step - loss: 0.0172 - accuracy: 0.9932 - val_loss: 0.9346 - val_accuracy: 0.8860
# Epoch 474/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 1.1255 - val_accuracy: 0.8862
# Epoch 475/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 1.0054 - val_accuracy: 0.8862
# Epoch 476/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0138 - accuracy: 0.9943 - val_loss: 0.9465 - val_accuracy: 0.8860
# Epoch 477/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 1.0684 - val_accuracy: 0.8854
# Epoch 478/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0137 - accuracy: 0.9943 - val_loss: 1.1385 - val_accuracy: 0.8851
# Epoch 479/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 1.0075 - val_accuracy: 0.8846
# Epoch 480/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0141 - accuracy: 0.9948 - val_loss: 0.9826 - val_accuracy: 0.8840
# Epoch 481/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0120 - accuracy: 0.9950 - val_loss: 1.2366 - val_accuracy: 0.8865
# Epoch 482/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0126 - accuracy: 0.9941 - val_loss: 1.2593 - val_accuracy: 0.8879
# Epoch 483/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0151 - accuracy: 0.9944 - val_loss: 1.0634 - val_accuracy: 0.8857
# Epoch 484/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0150 - accuracy: 0.9939 - val_loss: 0.9182 - val_accuracy: 0.8849
# Epoch 485/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0139 - accuracy: 0.9946 - val_loss: 0.9435 - val_accuracy: 0.8827
# Epoch 486/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0140 - accuracy: 0.9949 - val_loss: 0.8814 - val_accuracy: 0.8832
# Epoch 487/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0147 - accuracy: 0.9944 - val_loss: 0.8781 - val_accuracy: 0.8829
# Epoch 488/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0134 - accuracy: 0.9951 - val_loss: 0.9389 - val_accuracy: 0.8835
# Epoch 489/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 1.0663 - val_accuracy: 0.8846
# Epoch 490/500
# 456/456 [==============================] - 18s 39ms/step - loss: 0.0137 - accuracy: 0.9945 - val_loss: 1.0644 - val_accuracy: 0.8824
# Epoch 491/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0160 - accuracy: 0.9942 - val_loss: 1.0295 - val_accuracy: 0.8816
# Epoch 492/500
# 456/456 [==============================] - 20s 44ms/step - loss: 0.0146 - accuracy: 0.9947 - val_loss: 1.0559 - val_accuracy: 0.8832
# Epoch 493/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0120 - accuracy: 0.9947 - val_loss: 1.2223 - val_accuracy: 0.8816
# Epoch 494/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0144 - accuracy: 0.9949 - val_loss: 1.0289 - val_accuracy: 0.8827
# Epoch 495/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0135 - accuracy: 0.9947 - val_loss: 0.9792 - val_accuracy: 0.8827
# Epoch 496/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0124 - accuracy: 0.9949 - val_loss: 1.0793 - val_accuracy: 0.8838
# Epoch 497/500
# 456/456 [==============================] - 16s 36ms/step - loss: 0.0129 - accuracy: 0.9950 - val_loss: 1.0745 - val_accuracy: 0.8835
# Epoch 498/500
# 456/456 [==============================] - 17s 36ms/step - loss: 0.0151 - accuracy: 0.9943 - val_loss: 1.1079 - val_accuracy: 0.8838
# Epoch 499/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0145 - accuracy: 0.9942 - val_loss: 0.9464 - val_accuracy: 0.8840
# Epoch 500/500
# 456/456 [==============================] - 17s 37ms/step - loss: 0.0118 - accuracy: 0.9950 - val_loss: 1.2028 - val_accuracy: 0.8821
# 143/143 [==============================] - 3s 14ms/step - loss: 1.2222 - accuracy: 0.8833
# Test Loss: 1.222166657447815
# Test Accuracy: 0.8832821249961853

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from sklearn.metrics import classification_report

# Generate predictions
y_pred = model.predict(X_test_padded)
y_pred_classes = np.argmax(y_pred, axis=1)

# Print classification report
print(classification_report(y_test, y_pred_classes))
# Out:
# 143/143 [==============================] - 3s 12ms/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      2277
#            1       0.88      0.88      0.88      2281
#
#     accuracy                           0.88      4558
#    macro avg       0.88      0.88      0.88      4558
# weighted avg       0.88      0.88      0.88      4558

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


# Compute the confusion matrix
cm = confusion_matrix(y_test, np.round(y_pred[:, 1]))  # Use np.round for thresholding probabilities

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Negative", "Positive"])
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


# Compute ROC curve and AUC for the positive class
fpr, tpr, _ = roc_curve(y_test, y_pred[:, 1])  # Use y_pred[:, 1] for positive class
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Binary Classification (Positive vs. Negative)')
plt.legend(loc="lower right")
plt.show()

# %%
# Assuming 2 classes, adjust accordingly
negative_class_index = 0  # Index of the negative class
positive_class_index = 1  # Index of the positive class

# Calculate ROC curve for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(2):
    if i == negative_class_index:
        fpr['negative'], tpr['negative'], _ = roc_curve(y_test_one_hot[:, i], y_pred[:, i])
        roc_auc['negative'] = auc(fpr['negative'], tpr['negative'])
    elif i == positive_class_index:
        fpr['positive'], tpr['positive'], _ = roc_curve(y_test_one_hot[:, i], y_pred[:, i])
        roc_auc['positive'] = auc(fpr['positive'], tpr['positive'])

# Compute micro-average ROC curve and AUC
fpr_micro, tpr_micro, _ = roc_curve(y_test_one_hot.ravel(), y_pred.ravel())
roc_auc_micro = auc(fpr_micro, tpr_micro)

# Compute macro-average ROC curve and AUC
all_fpr = np.unique(np.concatenate([fpr['negative'], fpr['positive']]))
mean_tpr_negative = np.interp(all_fpr, fpr['negative'], tpr['negative'])
mean_tpr_positive = np.interp(all_fpr, fpr['positive'], tpr['positive'])
mean_tpr = (mean_tpr_negative + mean_tpr_positive) / 2
roc_auc_macro = auc(all_fpr, mean_tpr)
# Plot ROC curves
plt.figure(figsize=(10, 6))

# Plot micro-average ROC curve with a solid line
plt.plot(fpr_micro, tpr_micro, label='micro-average ROC curve (area = {:.2f})'.format(roc_auc_micro), linestyle='-', linewidth=2)

# Plot macro-average ROC curve with a solid line
plt.plot(all_fpr, mean_tpr, label='macro-average ROC curve (area = {:.2f})'.format(roc_auc_macro), linestyle='-', linewidth=2)

# Plot individual class ROC curves with different line styles
plt.plot(fpr['negative'], tpr['negative'], label='ROC curve of negative class (area = {:.2f})'.format(roc_auc['negative']), linestyle='--', linewidth=2)
plt.plot(fpr['positive'], tpr['positive'], label='ROC curve of positive class (area = {:.2f})'.format(roc_auc['positive']), linestyle=':', linewidth=2)

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc='lower right')
plt.show()

# %%
# Assuming 2 classes, adjust accordingly
negative_class_index = 0  # Index of the negative class
positive_class_index = 1  # Index of the positive class

# Calculate precision-recall curve for each class
precision = dict()
recall = dict()
pr_auc = dict()

for i in range(2):
    if i == negative_class_index:
        precision['negative'], recall['negative'], _ = precision_recall_curve(y_test_one_hot[:, i], y_pred[:, i])
        pr_auc['negative'] = auc(recall['negative'], precision['negative'])
    elif i == positive_class_index:
        precision['positive'], recall['positive'], _ = precision_recall_curve(y_test_one_hot[:, i], y_pred[:, i])
        pr_auc['positive'] = auc(recall['positive'], precision['positive'])

# Compute micro-average precision-recall curve and AUC
precision["micro"], recall["micro"], _ = precision_recall_curve(y_test_one_hot.ravel(), y_pred.ravel())
pr_auc["micro"] = auc(recall["micro"], precision["micro"])

# Compute macro-average precision-recall curve and AUC
all_recall = np.unique(np.concatenate([recall['negative'], recall['positive']]))
mean_precision_negative = np.interp(all_recall, recall['negative'][::-1], precision['negative'][::-1])
mean_precision_positive = np.interp(all_recall, recall['positive'][::-1], precision['positive'][::-1])
mean_precision = (mean_precision_negative + mean_precision_positive) / 2
precision["macro"] = mean_precision
recall["macro"] = all_recall
pr_auc["macro"] = auc(recall["macro"], precision["macro"])

# Plot Precision-Recall curves
plt.figure(figsize=(10, 6))

# Plot micro-average Precision-Recall curve
plt.plot(recall["micro"], precision["micro"], label='micro-average Precision-Recall curve (area = {:.2f})'.format(pr_auc["micro"]))

# Plot macro-average Precision-Recall curve
plt.plot(recall["macro"], precision["macro"], label='macro-average Precision-Recall curve (area = {:.2f})'.format(pr_auc["macro"]))

# Plot individual class Precision-Recall curves
plt.plot(recall['negative'], precision['negative'], label='Precision-Recall curve of negative class (area = {:.2f})'.format(pr_auc['negative']))
plt.plot(recall['positive'], precision['positive'], label='Precision-Recall curve of positive class (area = {:.2f})'.format(pr_auc['positive']))

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc='lower left')
plt.show()

# %%
# Save the model
model.save('Cnn_Bi_LSTM_final.h5')
from google.colab import files

files.download('Cnn_Bi_LSTM_final.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
