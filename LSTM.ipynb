# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
import pandas as pd
from nltk.stem import WordNetLemmatizer
from imblearn.over_sampling import SMOTE

from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import GlobalMaxPooling1D
from keras.layers import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
movie_reviews = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/new_data.csv")

movie_reviews.isnull().values.any()

movie_reviews.shape
# Out:
# (22788, 2)

# %%
movie_reviews.head(20)
# Out:
#                                              comments sentiment
# 0   ~~মা শিক্ষিত না হলেও   ~~মায়ের শিক্ষা কখনো ছোট...  Positive
# 1   ৭বছর পর সাকিব খানের কোন ছবি দেখলাম।। এক কথায় অ...  Positive
# 2   আমার দেখা ইমনের সেরা অভিনয় এই মুভিতে  আর শাকিব...  Positive
# 3   আমার জিবনে প্রথম মুভি যে হলে গিয়ে দেখলাম ওনেক ...  Positive
# 4   সেই ২০১৯ থেকে অপেক্ষায় ছিলাম কবে ইউটিউবে আসবে ...  Positive
# 5             শাকিব খানের এই মুভিটি অনেক সুন্দর হয়েছে  Positive
# 6   বাংলা মুভির পাশে থাকার জন্য সবাইকে অসংখ্য ধন্য...  Positive
# 7   সময়ের সেরা ছবি পাসওয়ার্ড,সবাই বেশি বেশি দেখুন ...  Positive
# 8       বাংলাদেশের কিছুর অভাব  থাকলেও পাগলের অভাব নেই  Negative
# 9          শাকিব খান  ছাড়া কোনো কথা হবে না ইনশাআল্লাহ  Positive
# 10  যখন আমি বাংলা মুভি দেখি কেন যেন হতাশ হয়ে যায়...  Negative
# 11  সিনেমাটি হলে গিয়ে দেখা হয়নি, তাই অনেকদিন অপে...  Positive
# 12            মালেক আফসারী স্যার এর এক অসাধারণ সৃষ্টি  Positive
# 13                           ইমন এর অভিনয় জাস্ট অসাম🫰  Positive
# 14   এই মুভিটার জন্য  আমি খুব অপেক্ষায়   ছিলাম কবে...  Positive
# 15  যে আমাকে পেলে দ্বিতীয় কাউকে ভাববে না, তার প্রত...  Positive
# 16                             বস শাকিব খান মানে আগুন  Positive
# 17  পুলিশ কে  মেয়ের ছবি  দেখা  তখন আমি  হাসতে  হাস...  Negative
# 18  শাকিব খান,, বুবলি,,  অমিত হাসান,, শিবা শানু,, ...  Positive
# 19  অসাদারণ মুভি শাকিব খান আসল হিরো  ভালোভাবে নিলেননা  Positive

# %%
movie_reviews["comments"][18]
# Out:
# 'শাকিব খান,, বুবলি,,  অমিত হাসান,, শিবা শানু,, ডন ,,, বিশেষ করে ইমনের  এবং ট্যালেন্টেড মিশা সওদাগর সবাই মিলে দারুন একটা মুভি উপহার দিয়েছেন যদিও কাহিনী অনেক কিছু সমস্যা ছিলো তারপরেও অসম্ভব সুন্দর হইছে মুভিটি,,, এগিয়ে যাক শাকিব খানের পাশাপশি সবার বাংলাদেশের ভালো মুভি গুলো।।।।'

# %%
movie_reviews = movie_reviews.dropna(subset=['sentiment'])

# %%
movie_reviews['sentiment'] = movie_reviews['sentiment'].str.strip()

# %%
movie_reviews['sentiment'] = movie_reviews['sentiment'].str.lower()

# %%
print(movie_reviews['sentiment'].unique())
# Out:
# ['positive' 'negative']

# %%
print(movie_reviews['sentiment'].dtype)
# Out:
# object

# %%
movie_reviews['sentiment'] = movie_reviews['sentiment'].astype('category')

# %%
print(movie_reviews['sentiment'].dtype)
# Out:
# category

# %%
# !pip install bangla-stemmer
from bangla_stemmer.stemmer.stemmer import BanglaStemmer
nltk.download('punkt')
# !pip install bangla-stemmer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from imblearn.over_sampling import SMOTE
import nltk
nltk.download('wordnet')
# Out:
# Collecting bangla-stemmer
#   Downloading bangla_stemmer-1.0-py3-none-any.whl (9.1 kB)
# Installing collected packages: bangla-stemmer
# Successfully installed bangla-stemmer-1.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Requirement already satisfied: bangla-stemmer in /usr/local/lib/python3.10/dist-packages (1.0)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import pandas as pd

# Replace the file path with the correct path to your 'stopwords.txt' file
file_path = r'/content/drive/MyDrive/Colab Notebooks/stopwords.txt'
data1 = pd.read_table(file_path)

# %%
print(data1)
stop = data1['words'].tolist()
# Out:
#         words
# 0        অতএব
# 1         অথচ
# 2        অথবা
# 3    অনুযায়ী
# 4        অনেক
# ..        ...
# 393     হাজার
# 394    হিসাবে
# 395      হৈলে
# 396       হোক
# 397        হয়
#
# [398 rows x 1 columns]

# %%
# Define the preprocess_text function
def preprocess_text(text):
    if isinstance(text, str):
        # Convert to lowercase
        text = text.lower()

        # Remove special characters and numbers using regex
        text = re.sub(r"[^A-Za-zঀ-৾]+", ' ', text)

        # Apply stemming using BanglaStemmer
        text = stem_text(text)

        # Tokenize the text and remove custom stopwords
        tokens = nltk.word_tokenize(text)
        tokens = [token for token in tokens if token not in stop]

        # Lemmatize the tokens
        tokens = [lemmatizer.lemmatize(token) for token in tokens]

        # Join tokens back to text
        text = ' '.join(tokens)

        return text
    else:
        return ""  # Return an empty string for non-string inputs

# Function for text stemming
def stem_text(x):
    stemmer = BanglaStemmer()
    words = x.split(' ')
    stm = [stemmer.stem(w) for w in words]
    words = ' '.join(stm)
    return words

# %%
X = movie_reviews['comments'].apply(preprocess_text).tolist()
# Out:
# Streaming output truncated to the last 5000 lines.
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# ...
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied third rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..

# %%
X[18]
# Out:
# 'শাকিব খান বুব অমিত হাসান শিবা শানু ডন ইমন ট্যালেন্টেড মিশা সওদাগর সবা মিলে দারুন এক মুভি উপহ কাহিনী সমস্যা ছিলো তারপরে অসম্ভব সুন্দর হই মুভি এগিয়ে যাক শাকিব খান পাশাপশি বাংলাদেশের ভালো মুভি গুলো'

# %%
y = movie_reviews['sentiment']
y = np.array([ 1 if label == 'positive' else 0 for label in movie_reviews['sentiment']])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from imblearn.over_sampling import SMOTE
from bangla_stemmer.stemmer.stemmer import BanglaStemmer

# %%
# Preprocess X_train and X_test with stopwords removal
X_train_preprocessed = [preprocess_text(comment) for comment in X_train]
X_test_preprocessed = [preprocess_text(comment) for comment in X_test]

# Create and fit the tokenizer
tokenizer = Tokenizer(num_words=5000, oov_token='<UNK>')
tokenizer.fit_on_texts(X_train_preprocessed)

# Get the vocab_size from the tokenizer
vocab_size = len(tokenizer.word_index) + 1

# Convert text data to sequences and pad them
X_train_sequences = tokenizer.texts_to_sequences(X_train_preprocessed)
X_test_sequences = tokenizer.texts_to_sequences(X_test_preprocessed)

maxlen = 1000
X_train_padded = pad_sequences(X_train_sequences, padding='post', maxlen=maxlen)
X_test_padded = pad_sequences(X_test_sequences, padding='post', maxlen=maxlen)

# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_train_padded, y_train = smote.fit_resample(X_train_padded, y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# ...
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..

# %%
import seaborn as sns
import matplotlib.pyplot as plt

order = ["positive", "negative"]
sns.countplot(x='sentiment', data=movie_reviews, order=order)
plt.xlabel('sentiment')
plt.xticks(rotation=45)
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Reshape



# Convert labels to one-hot encoded format
y_train_one_hot = to_categorical(y_train, num_classes=2)
y_test_one_hot = to_categorical(y_test, num_classes=2)

# Model architecture
vocab_size = 10000  # Replace with your vocabulary size
embedding_dim = 50
maxlen = 1000 # Replace with your sequence length

model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=maxlen))
model.add(Conv1D(128, 5, activation='relu'))
model.add(MaxPooling1D())
model.add(Flatten())  # Flatten the 2D output to 1D
model.add(Dense(64, activation='relu'))
model.add(Reshape((64, 1)))  # Reshape to (timesteps, features) for LSTM
model.add(LSTM(64))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Model training
epochs = 500
batch_size = 32
model.fit(X_train_padded, y_train_one_hot, epochs=epochs, batch_size=batch_size, validation_split=0.2)

# Model evaluation
loss, accuracy = model.evaluate(X_test_padded, y_test_one_hot)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Model prediction and classification report
y_pred = model.predict(X_test_padded)
y_pred_classes = np.argmax(y_pred, axis=1)

print(classification_report(y_test, y_pred_classes))
# Out:
# Epoch 1/500
# 456/456 [==============================] - 52s 87ms/step - loss: 0.5116 - accuracy: 0.7181 - val_loss: 0.3057 - val_accuracy: 0.8821
# Epoch 2/500
# 456/456 [==============================] - 8s 18ms/step - loss: 0.2617 - accuracy: 0.9081 - val_loss: 0.2726 - val_accuracy: 0.9002
# Epoch 3/500
# 456/456 [==============================] - 9s 19ms/step - loss: 0.1874 - accuracy: 0.9390 - val_loss: 0.2723 - val_accuracy: 0.8964
# Epoch 4/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.1445 - accuracy: 0.9571 - val_loss: 0.2819 - val_accuracy: 0.8920
# Epoch 5/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.1133 - accuracy: 0.9661 - val_loss: 0.3569 - val_accuracy: 0.8904
# Epoch 6/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.1050 - accuracy: 0.9683 - val_loss: 0.3398 - val_accuracy: 0.8912
# Epoch 7/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0887 - accuracy: 0.9759 - val_loss: 0.3918 - val_accuracy: 0.8895
# Epoch 8/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0742 - accuracy: 0.9797 - val_loss: 0.4592 - val_accuracy: 0.8906
# Epoch 9/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0703 - accuracy: 0.9796 - val_loss: 0.4479 - val_accuracy: 0.8840
# Epoch 10/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0619 - accuracy: 0.9820 - val_loss: 0.4564 - val_accuracy: 0.8851
# Epoch 11/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0538 - accuracy: 0.9844 - val_loss: 0.5145 - val_accuracy: 0.8824
# Epoch 12/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0489 - accuracy: 0.9858 - val_loss: 0.6061 - val_accuracy: 0.8788
# Epoch 13/500
# 456/456 [==============================] - 8s 17ms/step - loss: 0.0450 - accuracy: 0.9866 - val_loss: 0.5787 - val_accuracy: 0.8777
# Epoch 14/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0486 - accuracy: 0.9847 - val_loss: 0.5462 - val_accuracy: 0.8810
# Epoch 15/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0364 - accuracy: 0.9887 - val_loss: 0.6706 - val_accuracy: 0.8794
# Epoch 16/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0365 - accuracy: 0.9894 - val_loss: 0.7523 - val_accuracy: 0.8783
# Epoch 17/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0345 - accuracy: 0.9898 - val_loss: 0.6284 - val_accuracy: 0.8786
# Epoch 18/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0351 - accuracy: 0.9892 - val_loss: 0.6306 - val_accuracy: 0.8761
# Epoch 19/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0299 - accuracy: 0.9907 - val_loss: 0.8963 - val_accuracy: 0.8805
# Epoch 20/500
# 456/456 [==============================] - 8s 18ms/step - loss: 0.0278 - accuracy: 0.9907 - val_loss: 0.7608 - val_accuracy: 0.8780
# Epoch 21/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0273 - accuracy: 0.9905 - val_loss: 0.7425 - val_accuracy: 0.8786
# Epoch 22/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0256 - accuracy: 0.9915 - val_loss: 0.7094 - val_accuracy: 0.8753
# Epoch 23/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0240 - accuracy: 0.9907 - val_loss: 0.8400 - val_accuracy: 0.8788
# Epoch 24/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0209 - accuracy: 0.9925 - val_loss: 0.8256 - val_accuracy: 0.8777
# Epoch 25/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 1.0077 - val_accuracy: 0.8810
# Epoch 26/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0252 - accuracy: 0.9920 - val_loss: 0.8339 - val_accuracy: 0.8810
# Epoch 27/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0247 - accuracy: 0.9902 - val_loss: 0.7876 - val_accuracy: 0.8786
# Epoch 28/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0243 - accuracy: 0.9919 - val_loss: 0.8302 - val_accuracy: 0.8805
# Epoch 29/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0202 - accuracy: 0.9933 - val_loss: 0.9163 - val_accuracy: 0.8769
# Epoch 30/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0195 - accuracy: 0.9925 - val_loss: 1.1790 - val_accuracy: 0.8753
# Epoch 31/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0181 - accuracy: 0.9931 - val_loss: 1.1921 - val_accuracy: 0.8734
# Epoch 32/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0193 - accuracy: 0.9929 - val_loss: 1.0347 - val_accuracy: 0.8777
# Epoch 33/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 1.0004 - val_accuracy: 0.8769
# Epoch 34/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0191 - accuracy: 0.9927 - val_loss: 0.9156 - val_accuracy: 0.8772
# Epoch 35/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 1.1374 - val_accuracy: 0.8739
# Epoch 36/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0192 - accuracy: 0.9931 - val_loss: 0.9833 - val_accuracy: 0.8761
# Epoch 37/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0193 - accuracy: 0.9933 - val_loss: 1.0423 - val_accuracy: 0.8772
# Epoch 38/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0175 - accuracy: 0.9939 - val_loss: 1.0581 - val_accuracy: 0.8783
# Epoch 39/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 1.1293 - val_accuracy: 0.8725
# Epoch 40/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0158 - accuracy: 0.9938 - val_loss: 1.2197 - val_accuracy: 0.8775
# Epoch 41/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0176 - accuracy: 0.9934 - val_loss: 1.0054 - val_accuracy: 0.8750
# Epoch 42/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 1.0703 - val_accuracy: 0.8717
# Epoch 43/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0156 - accuracy: 0.9941 - val_loss: 1.2248 - val_accuracy: 0.8758
# Epoch 44/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0140 - accuracy: 0.9947 - val_loss: 1.3100 - val_accuracy: 0.8734
# Epoch 45/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0138 - accuracy: 0.9949 - val_loss: 1.2028 - val_accuracy: 0.8701
# Epoch 46/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0169 - accuracy: 0.9938 - val_loss: 0.9476 - val_accuracy: 0.8712
# Epoch 47/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0223 - accuracy: 0.9924 - val_loss: 0.9058 - val_accuracy: 0.8788
# Epoch 48/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0172 - accuracy: 0.9940 - val_loss: 1.1536 - val_accuracy: 0.8794
# Epoch 49/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0155 - accuracy: 0.9941 - val_loss: 1.0586 - val_accuracy: 0.8780
# Epoch 50/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0147 - accuracy: 0.9942 - val_loss: 1.1553 - val_accuracy: 0.8791
# Epoch 51/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0132 - accuracy: 0.9945 - val_loss: 1.4742 - val_accuracy: 0.8805
# Epoch 52/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0148 - accuracy: 0.9942 - val_loss: 1.1042 - val_accuracy: 0.8769
# Epoch 53/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0147 - accuracy: 0.9938 - val_loss: 1.2821 - val_accuracy: 0.8786
# Epoch 54/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0143 - accuracy: 0.9942 - val_loss: 1.0663 - val_accuracy: 0.8794
# Epoch 55/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0136 - accuracy: 0.9944 - val_loss: 1.3649 - val_accuracy: 0.8799
# Epoch 56/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0124 - accuracy: 0.9944 - val_loss: 1.1227 - val_accuracy: 0.8777
# Epoch 57/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0135 - accuracy: 0.9943 - val_loss: 1.1827 - val_accuracy: 0.8802
# Epoch 58/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0130 - accuracy: 0.9947 - val_loss: 1.2351 - val_accuracy: 0.8788
# Epoch 59/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0160 - accuracy: 0.9936 - val_loss: 0.9567 - val_accuracy: 0.8764
# Epoch 60/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0156 - accuracy: 0.9942 - val_loss: 1.2925 - val_accuracy: 0.8717
# Epoch 61/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 1.1437 - val_accuracy: 0.8808
# Epoch 62/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0164 - accuracy: 0.9935 - val_loss: 0.9421 - val_accuracy: 0.8761
# Epoch 63/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0175 - accuracy: 0.9935 - val_loss: 1.1140 - val_accuracy: 0.8816
# Epoch 64/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0137 - accuracy: 0.9949 - val_loss: 1.2730 - val_accuracy: 0.8731
# Epoch 65/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0121 - accuracy: 0.9944 - val_loss: 1.3164 - val_accuracy: 0.8725
# Epoch 66/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0120 - accuracy: 0.9949 - val_loss: 1.4335 - val_accuracy: 0.8745
# Epoch 67/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0127 - accuracy: 0.9947 - val_loss: 1.2123 - val_accuracy: 0.8747
# Epoch 68/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0129 - accuracy: 0.9944 - val_loss: 1.2341 - val_accuracy: 0.8745
# Epoch 69/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0173 - accuracy: 0.9932 - val_loss: 1.2284 - val_accuracy: 0.8725
# Epoch 70/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0144 - accuracy: 0.9940 - val_loss: 1.0981 - val_accuracy: 0.8761
# Epoch 71/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0123 - accuracy: 0.9949 - val_loss: 1.1671 - val_accuracy: 0.8769
# Epoch 72/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0125 - accuracy: 0.9947 - val_loss: 1.2675 - val_accuracy: 0.8775
# Epoch 73/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0116 - accuracy: 0.9947 - val_loss: 1.3771 - val_accuracy: 0.8783
# Epoch 74/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0126 - accuracy: 0.9945 - val_loss: 1.4705 - val_accuracy: 0.8736
# Epoch 75/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0127 - accuracy: 0.9943 - val_loss: 1.4273 - val_accuracy: 0.8709
# Epoch 76/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 1.0446 - val_accuracy: 0.8764
# Epoch 77/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 1.0722 - val_accuracy: 0.8761
# Epoch 78/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0125 - accuracy: 0.9953 - val_loss: 1.3535 - val_accuracy: 0.8731
# Epoch 79/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0126 - accuracy: 0.9946 - val_loss: 1.3275 - val_accuracy: 0.8753
# Epoch 80/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0118 - accuracy: 0.9951 - val_loss: 1.4073 - val_accuracy: 0.8731
# Epoch 81/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0120 - accuracy: 0.9951 - val_loss: 1.5581 - val_accuracy: 0.8772
# Epoch 82/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0133 - accuracy: 0.9949 - val_loss: 1.2802 - val_accuracy: 0.8745
# Epoch 83/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0130 - accuracy: 0.9941 - val_loss: 1.0838 - val_accuracy: 0.8783
# Epoch 84/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0146 - accuracy: 0.9941 - val_loss: 1.4979 - val_accuracy: 0.8725
# Epoch 85/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0133 - accuracy: 0.9951 - val_loss: 1.3096 - val_accuracy: 0.8840
# Epoch 86/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0145 - accuracy: 0.9945 - val_loss: 1.1726 - val_accuracy: 0.8816
# Epoch 87/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0126 - accuracy: 0.9949 - val_loss: 1.0836 - val_accuracy: 0.8808
# Epoch 88/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0122 - accuracy: 0.9948 - val_loss: 1.3605 - val_accuracy: 0.8764
# Epoch 89/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0119 - accuracy: 0.9945 - val_loss: 1.0692 - val_accuracy: 0.8777
# Epoch 90/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0118 - accuracy: 0.9953 - val_loss: 1.2329 - val_accuracy: 0.8794
# Epoch 91/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0154 - accuracy: 0.9942 - val_loss: 1.2635 - val_accuracy: 0.8758
# Epoch 92/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0122 - accuracy: 0.9948 - val_loss: 1.3202 - val_accuracy: 0.8772
# Epoch 93/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0113 - accuracy: 0.9949 - val_loss: 1.3550 - val_accuracy: 0.8775
# Epoch 94/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0111 - accuracy: 0.9951 - val_loss: 1.4398 - val_accuracy: 0.8775
# Epoch 95/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0120 - accuracy: 0.9951 - val_loss: 1.3871 - val_accuracy: 0.8780
# Epoch 96/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0124 - accuracy: 0.9947 - val_loss: 1.4461 - val_accuracy: 0.8728
# Epoch 97/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0150 - accuracy: 0.9945 - val_loss: 1.1707 - val_accuracy: 0.8747
# Epoch 98/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0153 - accuracy: 0.9944 - val_loss: 0.7427 - val_accuracy: 0.8794
# Epoch 99/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0166 - accuracy: 0.9938 - val_loss: 0.8149 - val_accuracy: 0.8824
# Epoch 100/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0118 - accuracy: 0.9951 - val_loss: 1.0537 - val_accuracy: 0.8857
# Epoch 101/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0109 - accuracy: 0.9953 - val_loss: 1.2232 - val_accuracy: 0.8827
# Epoch 102/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 1.0518 - val_accuracy: 0.8851
# Epoch 103/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0112 - accuracy: 0.9949 - val_loss: 1.1022 - val_accuracy: 0.8819
# Epoch 104/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0119 - accuracy: 0.9951 - val_loss: 1.3842 - val_accuracy: 0.8821
# Epoch 105/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0115 - accuracy: 0.9949 - val_loss: 1.2729 - val_accuracy: 0.8832
# Epoch 106/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0125 - accuracy: 0.9951 - val_loss: 1.1936 - val_accuracy: 0.8797
# Epoch 107/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0141 - accuracy: 0.9945 - val_loss: 0.9943 - val_accuracy: 0.8816
# Epoch 108/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 1.1163 - val_accuracy: 0.8758
# Epoch 109/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0117 - accuracy: 0.9949 - val_loss: 1.2471 - val_accuracy: 0.8797
# Epoch 110/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0110 - accuracy: 0.9955 - val_loss: 1.2684 - val_accuracy: 0.8766
# Epoch 111/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 1.4081 - val_accuracy: 0.8750
# Epoch 112/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0118 - accuracy: 0.9952 - val_loss: 1.3588 - val_accuracy: 0.8802
# Epoch 113/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0132 - accuracy: 0.9949 - val_loss: 1.1825 - val_accuracy: 0.8761
# Epoch 114/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0113 - accuracy: 0.9953 - val_loss: 1.3853 - val_accuracy: 0.8783
# Epoch 115/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0121 - accuracy: 0.9951 - val_loss: 1.1198 - val_accuracy: 0.8840
# Epoch 116/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0138 - accuracy: 0.9944 - val_loss: 1.3148 - val_accuracy: 0.8843
# Epoch 117/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0123 - accuracy: 0.9951 - val_loss: 1.2575 - val_accuracy: 0.8860
# Epoch 118/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0119 - accuracy: 0.9947 - val_loss: 1.2245 - val_accuracy: 0.8829
# Epoch 119/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0131 - accuracy: 0.9947 - val_loss: 0.9408 - val_accuracy: 0.8827
# Epoch 120/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0129 - accuracy: 0.9951 - val_loss: 1.3615 - val_accuracy: 0.8788
# Epoch 121/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 1.4174 - val_accuracy: 0.8835
# Epoch 122/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0108 - accuracy: 0.9952 - val_loss: 1.5023 - val_accuracy: 0.8802
# Epoch 123/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0111 - accuracy: 0.9951 - val_loss: 1.4779 - val_accuracy: 0.8805
# Epoch 124/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0110 - accuracy: 0.9952 - val_loss: 1.5651 - val_accuracy: 0.8816
# Epoch 125/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0111 - accuracy: 0.9951 - val_loss: 1.5295 - val_accuracy: 0.8832
# Epoch 126/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0107 - accuracy: 0.9956 - val_loss: 1.5285 - val_accuracy: 0.8821
# Epoch 127/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0120 - accuracy: 0.9949 - val_loss: 1.5515 - val_accuracy: 0.8805
# Epoch 128/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0144 - accuracy: 0.9946 - val_loss: 0.8207 - val_accuracy: 0.8654
# Epoch 129/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0135 - accuracy: 0.9946 - val_loss: 1.3206 - val_accuracy: 0.8797
# Epoch 130/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0116 - accuracy: 0.9949 - val_loss: 1.5237 - val_accuracy: 0.8832
# Epoch 131/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0109 - accuracy: 0.9950 - val_loss: 1.5641 - val_accuracy: 0.8827
# Epoch 132/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0108 - accuracy: 0.9949 - val_loss: 1.5394 - val_accuracy: 0.8829
# Epoch 133/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 1.6513 - val_accuracy: 0.8835
# Epoch 134/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0109 - accuracy: 0.9952 - val_loss: 1.5699 - val_accuracy: 0.8821
# Epoch 135/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 1.3597 - val_accuracy: 0.8783
# Epoch 136/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 1.4152 - val_accuracy: 0.8829
# Epoch 137/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 1.5081 - val_accuracy: 0.8766
# Epoch 138/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0107 - accuracy: 0.9949 - val_loss: 1.5639 - val_accuracy: 0.8769
# Epoch 139/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0116 - accuracy: 0.9949 - val_loss: 1.6366 - val_accuracy: 0.8786
# Epoch 140/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 1.6470 - val_accuracy: 0.8780
# Epoch 141/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 1.6429 - val_accuracy: 0.8788
# Epoch 142/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0108 - accuracy: 0.9954 - val_loss: 1.6203 - val_accuracy: 0.8799
# Epoch 143/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0119 - accuracy: 0.9947 - val_loss: 1.5743 - val_accuracy: 0.8857
# Epoch 144/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0115 - accuracy: 0.9949 - val_loss: 1.3384 - val_accuracy: 0.8791
# Epoch 145/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0123 - accuracy: 0.9947 - val_loss: 1.4517 - val_accuracy: 0.8766
# Epoch 146/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0113 - accuracy: 0.9950 - val_loss: 1.6836 - val_accuracy: 0.8802
# Epoch 147/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0133 - accuracy: 0.9951 - val_loss: 1.2624 - val_accuracy: 0.8819
# Epoch 148/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0135 - accuracy: 0.9945 - val_loss: 1.2405 - val_accuracy: 0.8827
# Epoch 149/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0111 - accuracy: 0.9949 - val_loss: 1.4856 - val_accuracy: 0.8816
# Epoch 150/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0110 - accuracy: 0.9950 - val_loss: 1.5490 - val_accuracy: 0.8805
# Epoch 151/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 1.7291 - val_accuracy: 0.8810
# Epoch 152/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0110 - accuracy: 0.9953 - val_loss: 1.7474 - val_accuracy: 0.8791
# Epoch 153/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9954 - val_loss: 1.6392 - val_accuracy: 0.8816
# Epoch 154/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0126 - accuracy: 0.9951 - val_loss: 1.0139 - val_accuracy: 0.8843
# Epoch 155/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0114 - accuracy: 0.9955 - val_loss: 1.5188 - val_accuracy: 0.8854
# Epoch 156/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 1.6511 - val_accuracy: 0.8813
# Epoch 157/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 1.7437 - val_accuracy: 0.8840
# Epoch 158/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0206 - accuracy: 0.9931 - val_loss: 0.7969 - val_accuracy: 0.8599
# Epoch 159/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0223 - accuracy: 0.9931 - val_loss: 1.3602 - val_accuracy: 0.8747
# Epoch 160/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0142 - accuracy: 0.9950 - val_loss: 1.1250 - val_accuracy: 0.8745
# Epoch 161/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0122 - accuracy: 0.9951 - val_loss: 1.2235 - val_accuracy: 0.8739
# Epoch 162/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0121 - accuracy: 0.9953 - val_loss: 1.0329 - val_accuracy: 0.8816
# Epoch 163/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 1.3209 - val_accuracy: 0.8786
# Epoch 164/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 1.3675 - val_accuracy: 0.8775
# Epoch 165/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0109 - accuracy: 0.9951 - val_loss: 1.4101 - val_accuracy: 0.8788
# Epoch 166/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0114 - accuracy: 0.9952 - val_loss: 1.3353 - val_accuracy: 0.8794
# Epoch 167/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 1.5860 - val_accuracy: 0.8777
# Epoch 168/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0120 - accuracy: 0.9951 - val_loss: 1.4178 - val_accuracy: 0.8794
# Epoch 169/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0107 - accuracy: 0.9953 - val_loss: 1.6282 - val_accuracy: 0.8808
# Epoch 170/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0109 - accuracy: 0.9951 - val_loss: 1.6100 - val_accuracy: 0.8816
# Epoch 171/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0111 - accuracy: 0.9955 - val_loss: 1.8736 - val_accuracy: 0.8824
# Epoch 172/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 1.7129 - val_accuracy: 0.8813
# Epoch 173/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0111 - accuracy: 0.9954 - val_loss: 1.7153 - val_accuracy: 0.8805
# Epoch 174/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0105 - accuracy: 0.9951 - val_loss: 1.8520 - val_accuracy: 0.8813
# Epoch 175/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0111 - accuracy: 0.9952 - val_loss: 1.7734 - val_accuracy: 0.8794
# Epoch 176/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0110 - accuracy: 0.9952 - val_loss: 1.7731 - val_accuracy: 0.8797
# Epoch 177/500
# 456/456 [==============================] - 8s 17ms/step - loss: 0.0112 - accuracy: 0.9951 - val_loss: 1.7985 - val_accuracy: 0.8813
# Epoch 178/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0125 - accuracy: 0.9951 - val_loss: 1.5593 - val_accuracy: 0.8799
# Epoch 179/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0145 - accuracy: 0.9943 - val_loss: 1.2957 - val_accuracy: 0.8799
# Epoch 180/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 1.3588 - val_accuracy: 0.8786
# Epoch 181/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0121 - accuracy: 0.9955 - val_loss: 1.2305 - val_accuracy: 0.8772
# Epoch 182/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0121 - accuracy: 0.9950 - val_loss: 1.3512 - val_accuracy: 0.8846
# Epoch 183/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0113 - accuracy: 0.9949 - val_loss: 1.2688 - val_accuracy: 0.8780
# Epoch 184/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 1.4169 - val_accuracy: 0.8797
# Epoch 185/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0108 - accuracy: 0.9951 - val_loss: 1.3703 - val_accuracy: 0.8799
# Epoch 186/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0114 - accuracy: 0.9951 - val_loss: 1.3580 - val_accuracy: 0.8819
# Epoch 187/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9952 - val_loss: 1.4191 - val_accuracy: 0.8797
# Epoch 188/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0159 - accuracy: 0.9941 - val_loss: 1.3049 - val_accuracy: 0.8775
# Epoch 189/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0121 - accuracy: 0.9948 - val_loss: 1.6076 - val_accuracy: 0.8797
# Epoch 190/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0119 - accuracy: 0.9953 - val_loss: 1.6247 - val_accuracy: 0.8829
# Epoch 191/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9951 - val_loss: 1.7775 - val_accuracy: 0.8840
# Epoch 192/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0109 - accuracy: 0.9953 - val_loss: 1.6167 - val_accuracy: 0.8835
# Epoch 193/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 1.7640 - val_accuracy: 0.8838
# Epoch 194/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 1.8177 - val_accuracy: 0.8819
# Epoch 195/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 1.8851 - val_accuracy: 0.8862
# Epoch 196/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0119 - accuracy: 0.9953 - val_loss: 1.3221 - val_accuracy: 0.8701
# Epoch 197/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0118 - accuracy: 0.9951 - val_loss: 1.0196 - val_accuracy: 0.8761
# Epoch 198/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0127 - accuracy: 0.9947 - val_loss: 1.5880 - val_accuracy: 0.8775
# Epoch 199/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0108 - accuracy: 0.9955 - val_loss: 1.6994 - val_accuracy: 0.8829
# Epoch 200/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0114 - accuracy: 0.9949 - val_loss: 1.7171 - val_accuracy: 0.8808
# Epoch 201/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 1.6339 - val_accuracy: 0.8821
# Epoch 202/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9954 - val_loss: 1.7989 - val_accuracy: 0.8791
# Epoch 203/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 1.6217 - val_accuracy: 0.8797
# Epoch 204/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0103 - accuracy: 0.9954 - val_loss: 1.7570 - val_accuracy: 0.8832
# Epoch 205/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 1.5604 - val_accuracy: 0.8788
# Epoch 206/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0121 - accuracy: 0.9950 - val_loss: 1.5138 - val_accuracy: 0.8766
# Epoch 207/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0110 - accuracy: 0.9952 - val_loss: 1.7170 - val_accuracy: 0.8827
# Epoch 208/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0119 - accuracy: 0.9954 - val_loss: 1.5609 - val_accuracy: 0.8799
# Epoch 209/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0108 - accuracy: 0.9951 - val_loss: 1.6049 - val_accuracy: 0.8816
# Epoch 210/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9955 - val_loss: 1.6163 - val_accuracy: 0.8829
# Epoch 211/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0105 - accuracy: 0.9953 - val_loss: 1.7560 - val_accuracy: 0.8827
# Epoch 212/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0106 - accuracy: 0.9950 - val_loss: 1.6301 - val_accuracy: 0.8827
# Epoch 213/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0110 - accuracy: 0.9952 - val_loss: 1.6826 - val_accuracy: 0.8824
# Epoch 214/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 1.9776 - val_accuracy: 0.8829
# Epoch 215/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0106 - accuracy: 0.9951 - val_loss: 1.8090 - val_accuracy: 0.8843
# Epoch 216/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0105 - accuracy: 0.9953 - val_loss: 2.1725 - val_accuracy: 0.8794
# Epoch 217/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0116 - accuracy: 0.9952 - val_loss: 1.7075 - val_accuracy: 0.8799
# Epoch 218/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0126 - accuracy: 0.9947 - val_loss: 1.4873 - val_accuracy: 0.8745
# Epoch 219/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0110 - accuracy: 0.9954 - val_loss: 1.8034 - val_accuracy: 0.8791
# Epoch 220/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0105 - accuracy: 0.9953 - val_loss: 1.9492 - val_accuracy: 0.8797
# Epoch 221/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0109 - accuracy: 0.9953 - val_loss: 1.9971 - val_accuracy: 0.8810
# Epoch 222/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0102 - accuracy: 0.9953 - val_loss: 1.8971 - val_accuracy: 0.8808
# Epoch 223/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 1.9037 - val_accuracy: 0.8791
# Epoch 224/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0109 - accuracy: 0.9952 - val_loss: 1.8034 - val_accuracy: 0.8791
# Epoch 225/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0113 - accuracy: 0.9951 - val_loss: 1.9181 - val_accuracy: 0.8802
# Epoch 226/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0107 - accuracy: 0.9950 - val_loss: 1.8663 - val_accuracy: 0.8780
# Epoch 227/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0117 - accuracy: 0.9951 - val_loss: 1.5958 - val_accuracy: 0.8835
# Epoch 228/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0107 - accuracy: 0.9955 - val_loss: 1.9171 - val_accuracy: 0.8769
# Epoch 229/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9951 - val_loss: 2.0349 - val_accuracy: 0.8813
# Epoch 230/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 1.9949 - val_accuracy: 0.8769
# Epoch 231/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9952 - val_loss: 2.0942 - val_accuracy: 0.8753
# Epoch 232/500
# 456/456 [==============================] - 5s 12ms/step - loss: 0.0130 - accuracy: 0.9949 - val_loss: 1.7289 - val_accuracy: 0.8794
# Epoch 233/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0125 - accuracy: 0.9949 - val_loss: 1.6473 - val_accuracy: 0.8799
# Epoch 234/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0107 - accuracy: 0.9952 - val_loss: 1.9980 - val_accuracy: 0.8802
# Epoch 235/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0111 - accuracy: 0.9954 - val_loss: 1.8387 - val_accuracy: 0.8794
# Epoch 236/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0112 - accuracy: 0.9952 - val_loss: 2.1300 - val_accuracy: 0.8745
# Epoch 237/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0107 - accuracy: 0.9953 - val_loss: 1.9794 - val_accuracy: 0.8766
# Epoch 238/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0107 - accuracy: 0.9952 - val_loss: 2.0457 - val_accuracy: 0.8780
# Epoch 239/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.2868 - val_accuracy: 0.8780
# Epoch 240/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9954 - val_loss: 2.3594 - val_accuracy: 0.8780
# Epoch 241/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.2468 - val_accuracy: 0.8772
# Epoch 242/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0104 - accuracy: 0.9954 - val_loss: 2.1572 - val_accuracy: 0.8791
# Epoch 243/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 2.6274 - val_accuracy: 0.8766
# Epoch 244/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0134 - accuracy: 0.9951 - val_loss: 1.6717 - val_accuracy: 0.8819
# Epoch 245/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0123 - accuracy: 0.9947 - val_loss: 1.4798 - val_accuracy: 0.8849
# Epoch 246/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0110 - accuracy: 0.9953 - val_loss: 1.6861 - val_accuracy: 0.8849
# Epoch 247/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 1.8562 - val_accuracy: 0.8824
# Epoch 248/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0109 - accuracy: 0.9953 - val_loss: 2.0071 - val_accuracy: 0.8808
# Epoch 249/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0110 - accuracy: 0.9956 - val_loss: 1.8126 - val_accuracy: 0.8813
# Epoch 250/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0107 - accuracy: 0.9953 - val_loss: 1.9397 - val_accuracy: 0.8810
# Epoch 251/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 2.0284 - val_accuracy: 0.8810
# Epoch 252/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0104 - accuracy: 0.9950 - val_loss: 2.0320 - val_accuracy: 0.8821
# Epoch 253/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.1244 - val_accuracy: 0.8810
# Epoch 254/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0111 - accuracy: 0.9954 - val_loss: 1.8260 - val_accuracy: 0.8824
# Epoch 255/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 1.9589 - val_accuracy: 0.8794
# Epoch 256/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0109 - accuracy: 0.9951 - val_loss: 1.8679 - val_accuracy: 0.8794
# Epoch 257/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0126 - accuracy: 0.9951 - val_loss: 1.4282 - val_accuracy: 0.8794
# Epoch 258/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0110 - accuracy: 0.9953 - val_loss: 1.9081 - val_accuracy: 0.8797
# Epoch 259/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0110 - accuracy: 0.9950 - val_loss: 2.1738 - val_accuracy: 0.8777
# Epoch 260/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0108 - accuracy: 0.9952 - val_loss: 1.8754 - val_accuracy: 0.8827
# Epoch 261/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0114 - accuracy: 0.9952 - val_loss: 1.8583 - val_accuracy: 0.8838
# Epoch 262/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 1.9460 - val_accuracy: 0.8808
# Epoch 263/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0105 - accuracy: 0.9953 - val_loss: 2.1088 - val_accuracy: 0.8808
# Epoch 264/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9954 - val_loss: 2.4426 - val_accuracy: 0.8805
# Epoch 265/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0112 - accuracy: 0.9951 - val_loss: 1.7421 - val_accuracy: 0.8799
# Epoch 266/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 1.8695 - val_accuracy: 0.8816
# Epoch 267/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9952 - val_loss: 2.0915 - val_accuracy: 0.8813
# Epoch 268/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 2.0066 - val_accuracy: 0.8832
# Epoch 269/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0118 - accuracy: 0.9951 - val_loss: 1.8936 - val_accuracy: 0.8772
# Epoch 270/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0131 - accuracy: 0.9946 - val_loss: 2.2101 - val_accuracy: 0.8766
# Epoch 271/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0108 - accuracy: 0.9949 - val_loss: 2.2554 - val_accuracy: 0.8783
# Epoch 272/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9951 - val_loss: 2.2467 - val_accuracy: 0.8777
# Epoch 273/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9955 - val_loss: 2.3899 - val_accuracy: 0.8783
# Epoch 274/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9954 - val_loss: 2.2821 - val_accuracy: 0.8791
# Epoch 275/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.3408 - val_accuracy: 0.8783
# Epoch 276/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 2.4551 - val_accuracy: 0.8805
# Epoch 277/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 2.3554 - val_accuracy: 0.8808
# Epoch 278/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0104 - accuracy: 0.9957 - val_loss: 2.4417 - val_accuracy: 0.8805
# Epoch 279/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0105 - accuracy: 0.9954 - val_loss: 2.2823 - val_accuracy: 0.8777
# Epoch 280/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0105 - accuracy: 0.9952 - val_loss: 2.3976 - val_accuracy: 0.8797
# Epoch 281/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0106 - accuracy: 0.9954 - val_loss: 2.2517 - val_accuracy: 0.8805
# Epoch 282/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0109 - accuracy: 0.9953 - val_loss: 2.1193 - val_accuracy: 0.8808
# Epoch 283/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9952 - val_loss: 2.2346 - val_accuracy: 0.8750
# Epoch 284/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0155 - accuracy: 0.9954 - val_loss: 1.3224 - val_accuracy: 0.8816
# Epoch 285/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0110 - accuracy: 0.9953 - val_loss: 1.8861 - val_accuracy: 0.8758
# Epoch 286/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0116 - accuracy: 0.9954 - val_loss: 1.7762 - val_accuracy: 0.8777
# Epoch 287/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9952 - val_loss: 1.6735 - val_accuracy: 0.8794
# Epoch 288/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0105 - accuracy: 0.9953 - val_loss: 2.0952 - val_accuracy: 0.8745
# Epoch 289/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9954 - val_loss: 1.8677 - val_accuracy: 0.8772
# Epoch 290/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0122 - accuracy: 0.9952 - val_loss: 1.9466 - val_accuracy: 0.8799
# Epoch 291/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0137 - accuracy: 0.9949 - val_loss: 1.6559 - val_accuracy: 0.8728
# Epoch 292/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 1.8666 - val_accuracy: 0.8753
# Epoch 293/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 1.8441 - val_accuracy: 0.8764
# Epoch 294/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 1.9771 - val_accuracy: 0.8750
# Epoch 295/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0105 - accuracy: 0.9957 - val_loss: 2.1009 - val_accuracy: 0.8753
# Epoch 296/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0111 - accuracy: 0.9951 - val_loss: 1.8584 - val_accuracy: 0.8709
# Epoch 297/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0118 - accuracy: 0.9949 - val_loss: 1.3916 - val_accuracy: 0.8725
# Epoch 298/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0108 - accuracy: 0.9954 - val_loss: 2.2349 - val_accuracy: 0.8742
# Epoch 299/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0104 - accuracy: 0.9951 - val_loss: 2.2574 - val_accuracy: 0.8742
# Epoch 300/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0108 - accuracy: 0.9955 - val_loss: 2.5230 - val_accuracy: 0.8742
# Epoch 301/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0105 - accuracy: 0.9954 - val_loss: 2.3975 - val_accuracy: 0.8734
# Epoch 302/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0100 - accuracy: 0.9954 - val_loss: 2.4557 - val_accuracy: 0.8750
# Epoch 303/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9952 - val_loss: 2.4304 - val_accuracy: 0.8739
# Epoch 304/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0103 - accuracy: 0.9956 - val_loss: 2.4850 - val_accuracy: 0.8761
# Epoch 305/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9952 - val_loss: 2.4139 - val_accuracy: 0.8761
# Epoch 306/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0116 - accuracy: 0.9950 - val_loss: 2.3707 - val_accuracy: 0.8780
# Epoch 307/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0123 - accuracy: 0.9951 - val_loss: 2.1719 - val_accuracy: 0.8742
# Epoch 308/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 2.0450 - val_accuracy: 0.8799
# Epoch 309/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0118 - accuracy: 0.9951 - val_loss: 2.0985 - val_accuracy: 0.8761
# Epoch 310/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 2.2675 - val_accuracy: 0.8777
# Epoch 311/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 2.2544 - val_accuracy: 0.8775
# Epoch 312/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0103 - accuracy: 0.9953 - val_loss: 2.1600 - val_accuracy: 0.8794
# Epoch 313/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9954 - val_loss: 2.4693 - val_accuracy: 0.8799
# Epoch 314/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0105 - accuracy: 0.9956 - val_loss: 2.5061 - val_accuracy: 0.8802
# Epoch 315/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0111 - accuracy: 0.9951 - val_loss: 2.2483 - val_accuracy: 0.8808
# Epoch 316/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0113 - accuracy: 0.9955 - val_loss: 1.9673 - val_accuracy: 0.8791
# Epoch 317/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0125 - accuracy: 0.9951 - val_loss: 1.9927 - val_accuracy: 0.8758
# Epoch 318/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0114 - accuracy: 0.9953 - val_loss: 1.9575 - val_accuracy: 0.8802
# Epoch 319/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 1.9564 - val_accuracy: 0.8788
# Epoch 320/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0103 - accuracy: 0.9954 - val_loss: 2.0758 - val_accuracy: 0.8810
# Epoch 321/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0117 - accuracy: 0.9953 - val_loss: 1.9635 - val_accuracy: 0.8720
# Epoch 322/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0132 - accuracy: 0.9949 - val_loss: 1.5117 - val_accuracy: 0.8728
# Epoch 323/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 1.1990 - val_accuracy: 0.8720
# Epoch 324/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 1.2411 - val_accuracy: 0.8780
# Epoch 325/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0111 - accuracy: 0.9953 - val_loss: 1.3090 - val_accuracy: 0.8777
# Epoch 326/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0110 - accuracy: 0.9953 - val_loss: 1.3742 - val_accuracy: 0.8758
# Epoch 327/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 1.2802 - val_accuracy: 0.8775
# Epoch 328/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 1.1817 - val_accuracy: 0.8777
# Epoch 329/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 1.7069 - val_accuracy: 0.8739
# Epoch 330/500
# ...
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 2.0097 - val_accuracy: 0.8808
# Epoch 396/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0108 - accuracy: 0.9952 - val_loss: 2.6545 - val_accuracy: 0.8755
# Epoch 397/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0123 - accuracy: 0.9949 - val_loss: 2.0800 - val_accuracy: 0.8745
# Epoch 398/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9958 - val_loss: 2.3833 - val_accuracy: 0.8758
# Epoch 399/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 2.3657 - val_accuracy: 0.8747
# Epoch 400/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9953 - val_loss: 2.6247 - val_accuracy: 0.8739
# Epoch 401/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0101 - accuracy: 0.9954 - val_loss: 2.5455 - val_accuracy: 0.8742
# Epoch 402/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0106 - accuracy: 0.9951 - val_loss: 2.3774 - val_accuracy: 0.8747
# Epoch 403/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9955 - val_loss: 2.1617 - val_accuracy: 0.8764
# Epoch 404/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 2.1031 - val_accuracy: 0.8761
# Epoch 405/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0118 - accuracy: 0.9953 - val_loss: 2.6387 - val_accuracy: 0.8747
# Epoch 406/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0107 - accuracy: 0.9951 - val_loss: 2.3276 - val_accuracy: 0.8753
# Epoch 407/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0103 - accuracy: 0.9951 - val_loss: 2.5468 - val_accuracy: 0.8764
# Epoch 408/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0101 - accuracy: 0.9956 - val_loss: 2.6429 - val_accuracy: 0.8764
# Epoch 409/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0105 - accuracy: 0.9954 - val_loss: 2.7133 - val_accuracy: 0.8750
# Epoch 410/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0113 - accuracy: 0.9951 - val_loss: 2.7186 - val_accuracy: 0.8750
# Epoch 411/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0125 - accuracy: 0.9955 - val_loss: 2.7096 - val_accuracy: 0.8736
# Epoch 412/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0119 - accuracy: 0.9950 - val_loss: 2.0307 - val_accuracy: 0.8755
# Epoch 413/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0119 - accuracy: 0.9949 - val_loss: 1.8031 - val_accuracy: 0.8805
# Epoch 414/500
# 456/456 [==============================] - 6s 12ms/step - loss: 0.0105 - accuracy: 0.9953 - val_loss: 1.9588 - val_accuracy: 0.8761
# Epoch 415/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0113 - accuracy: 0.9955 - val_loss: 2.1142 - val_accuracy: 0.8769
# Epoch 416/500
# 456/456 [==============================] - 8s 17ms/step - loss: 0.0107 - accuracy: 0.9953 - val_loss: 2.1475 - val_accuracy: 0.8772
# Epoch 417/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0111 - accuracy: 0.9951 - val_loss: 1.9325 - val_accuracy: 0.8802
# Epoch 418/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9956 - val_loss: 2.1370 - val_accuracy: 0.8783
# Epoch 419/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 2.3925 - val_accuracy: 0.8777
# Epoch 420/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0102 - accuracy: 0.9955 - val_loss: 2.4950 - val_accuracy: 0.8791
# Epoch 421/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0106 - accuracy: 0.9951 - val_loss: 2.6151 - val_accuracy: 0.8783
# Epoch 422/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.3452 - val_accuracy: 0.8777
# Epoch 423/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9953 - val_loss: 2.7326 - val_accuracy: 0.8772
# Epoch 424/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 2.6499 - val_accuracy: 0.8780
# Epoch 425/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0105 - accuracy: 0.9952 - val_loss: 2.3595 - val_accuracy: 0.8808
# Epoch 426/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0105 - accuracy: 0.9952 - val_loss: 2.8367 - val_accuracy: 0.8734
# Epoch 427/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0145 - accuracy: 0.9945 - val_loss: 1.9185 - val_accuracy: 0.8753
# Epoch 428/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0123 - accuracy: 0.9951 - val_loss: 1.9806 - val_accuracy: 0.8810
# Epoch 429/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9951 - val_loss: 2.0118 - val_accuracy: 0.8783
# Epoch 430/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 2.1693 - val_accuracy: 0.8769
# Epoch 431/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9954 - val_loss: 2.2731 - val_accuracy: 0.8764
# Epoch 432/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9951 - val_loss: 2.3034 - val_accuracy: 0.8775
# Epoch 433/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0103 - accuracy: 0.9952 - val_loss: 2.2504 - val_accuracy: 0.8764
# Epoch 434/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0105 - accuracy: 0.9956 - val_loss: 2.3965 - val_accuracy: 0.8764
# Epoch 435/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0100 - accuracy: 0.9957 - val_loss: 2.4694 - val_accuracy: 0.8772
# Epoch 436/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 2.4677 - val_accuracy: 0.8775
# Epoch 437/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.3981 - val_accuracy: 0.8772
# Epoch 438/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0106 - accuracy: 0.9954 - val_loss: 2.6202 - val_accuracy: 0.8775
# Epoch 439/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.4241 - val_accuracy: 0.8755
# Epoch 440/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0106 - accuracy: 0.9951 - val_loss: 2.2780 - val_accuracy: 0.8761
# Epoch 441/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 2.1157 - val_accuracy: 0.8835
# Epoch 442/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0106 - accuracy: 0.9957 - val_loss: 2.5545 - val_accuracy: 0.8777
# Epoch 443/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0102 - accuracy: 0.9955 - val_loss: 2.9121 - val_accuracy: 0.8739
# Epoch 444/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 3.0009 - val_accuracy: 0.8747
# Epoch 445/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0116 - accuracy: 0.9955 - val_loss: 2.3373 - val_accuracy: 0.8714
# Epoch 446/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 2.8078 - val_accuracy: 0.8684
# Epoch 447/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9957 - val_loss: 2.7468 - val_accuracy: 0.8687
# Epoch 448/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9952 - val_loss: 2.8666 - val_accuracy: 0.8673
# Epoch 449/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0105 - accuracy: 0.9957 - val_loss: 2.4361 - val_accuracy: 0.8728
# Epoch 450/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9953 - val_loss: 2.3708 - val_accuracy: 0.8703
# Epoch 451/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0134 - accuracy: 0.9947 - val_loss: 2.1725 - val_accuracy: 0.8761
# Epoch 452/500
# 456/456 [==============================] - 8s 17ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 2.0101 - val_accuracy: 0.8758
# Epoch 453/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0113 - accuracy: 0.9954 - val_loss: 2.0859 - val_accuracy: 0.8783
# Epoch 454/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0111 - accuracy: 0.9954 - val_loss: 1.7393 - val_accuracy: 0.8797
# Epoch 455/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0115 - accuracy: 0.9949 - val_loss: 1.7331 - val_accuracy: 0.8745
# Epoch 456/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0122 - accuracy: 0.9953 - val_loss: 1.7244 - val_accuracy: 0.8766
# Epoch 457/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9950 - val_loss: 1.9176 - val_accuracy: 0.8772
# Epoch 458/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0108 - accuracy: 0.9955 - val_loss: 2.0384 - val_accuracy: 0.8769
# Epoch 459/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.2710 - val_accuracy: 0.8777
# Epoch 460/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0109 - accuracy: 0.9952 - val_loss: 2.2023 - val_accuracy: 0.8783
# Epoch 461/500
# 456/456 [==============================] - 8s 17ms/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 2.5342 - val_accuracy: 0.8775
# Epoch 462/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 2.5630 - val_accuracy: 0.8783
# Epoch 463/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0108 - accuracy: 0.9954 - val_loss: 2.1957 - val_accuracy: 0.8797
# Epoch 464/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0105 - accuracy: 0.9950 - val_loss: 2.6633 - val_accuracy: 0.8788
# Epoch 465/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9954 - val_loss: 2.6388 - val_accuracy: 0.8780
# Epoch 466/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0105 - accuracy: 0.9952 - val_loss: 2.7016 - val_accuracy: 0.8775
# Epoch 467/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0121 - accuracy: 0.9951 - val_loss: 1.9888 - val_accuracy: 0.8794
# Epoch 468/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.1324 - val_accuracy: 0.8777
# Epoch 469/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0110 - accuracy: 0.9951 - val_loss: 2.4553 - val_accuracy: 0.8734
# Epoch 470/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0123 - accuracy: 0.9951 - val_loss: 1.9794 - val_accuracy: 0.8742
# Epoch 471/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 2.2298 - val_accuracy: 0.8731
# Epoch 472/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0106 - accuracy: 0.9952 - val_loss: 2.3620 - val_accuracy: 0.8728
# Epoch 473/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9952 - val_loss: 2.4436 - val_accuracy: 0.8734
# Epoch 474/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9953 - val_loss: 2.5329 - val_accuracy: 0.8725
# Epoch 475/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0105 - accuracy: 0.9956 - val_loss: 2.6044 - val_accuracy: 0.8745
# Epoch 476/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0107 - accuracy: 0.9955 - val_loss: 2.5258 - val_accuracy: 0.8728
# Epoch 477/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9958 - val_loss: 2.6668 - val_accuracy: 0.8742
# Epoch 478/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0105 - accuracy: 0.9958 - val_loss: 2.7198 - val_accuracy: 0.8775
# Epoch 479/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0104 - accuracy: 0.9954 - val_loss: 2.7188 - val_accuracy: 0.8745
# Epoch 480/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 3.0860 - val_accuracy: 0.8750
# Epoch 481/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0119 - accuracy: 0.9953 - val_loss: 2.7484 - val_accuracy: 0.8755
# Epoch 482/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0119 - accuracy: 0.9952 - val_loss: 2.0056 - val_accuracy: 0.8769
# Epoch 483/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0121 - accuracy: 0.9944 - val_loss: 2.4158 - val_accuracy: 0.8651
# Epoch 484/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9954 - val_loss: 2.7949 - val_accuracy: 0.8783
# Epoch 485/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0105 - accuracy: 0.9954 - val_loss: 2.8437 - val_accuracy: 0.8786
# Epoch 486/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0104 - accuracy: 0.9957 - val_loss: 2.6537 - val_accuracy: 0.8775
# Epoch 487/500
# 456/456 [==============================] - 6s 14ms/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 2.9294 - val_accuracy: 0.8777
# Epoch 488/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0106 - accuracy: 0.9954 - val_loss: 2.7864 - val_accuracy: 0.8786
# Epoch 489/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0102 - accuracy: 0.9953 - val_loss: 3.0341 - val_accuracy: 0.8777
# Epoch 490/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0103 - accuracy: 0.9957 - val_loss: 2.8588 - val_accuracy: 0.8769
# Epoch 491/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0104 - accuracy: 0.9952 - val_loss: 2.9502 - val_accuracy: 0.8786
# Epoch 492/500
# 456/456 [==============================] - 7s 15ms/step - loss: 0.0104 - accuracy: 0.9954 - val_loss: 2.9692 - val_accuracy: 0.8777
# Epoch 493/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9956 - val_loss: 2.6700 - val_accuracy: 0.8761
# Epoch 494/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9954 - val_loss: 2.8072 - val_accuracy: 0.8777
# Epoch 495/500
# 456/456 [==============================] - 7s 14ms/step - loss: 0.0103 - accuracy: 0.9953 - val_loss: 3.1496 - val_accuracy: 0.8797
# Epoch 496/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 3.0561 - val_accuracy: 0.8788
# Epoch 497/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 3.1182 - val_accuracy: 0.8777
# Epoch 498/500
# 456/456 [==============================] - 7s 16ms/step - loss: 0.0110 - accuracy: 0.9953 - val_loss: 2.6678 - val_accuracy: 0.8775
# Epoch 499/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0107 - accuracy: 0.9951 - val_loss: 2.9913 - val_accuracy: 0.8780
# Epoch 500/500
# 456/456 [==============================] - 6s 13ms/step - loss: 0.0122 - accuracy: 0.9949 - val_loss: 2.4912 - val_accuracy: 0.8783
# 143/143 [==============================] - 2s 8ms/step - loss: 2.3189 - accuracy: 0.8802
# Test Loss: 2.318908214569092
# Test Accuracy: 0.8802106380462646
# 143/143 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      2277
#            1       0.89      0.86      0.88      2281
#
#     accuracy                           0.88      4558
#    macro avg       0.88      0.88      0.88      4558
# weighted avg       0.88      0.88      0.88      4558

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# Generate predictions
y_pred = model.predict(X_test_padded)
y_pred_classes = np.argmax(y_pred, axis=1)

# Print classification report
print(classification_report(y_test, y_pred_classes))
# Out:
# 143/143 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      2277
#            1       0.89      0.86      0.88      2281
#
#     accuracy                           0.88      4558
#    macro avg       0.88      0.88      0.88      4558
# weighted avg       0.88      0.88      0.88      4558

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


# Compute the confusion matrix
cm = confusion_matrix(y_test, np.round(y_pred[:, 1]))  # Use np.round for thresholding probabilities

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Negative", "Positive"])
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


# Compute ROC curve and AUC for the positive class
fpr, tpr, _ = roc_curve(y_test, y_pred[:, 1])  # Use y_pred[:, 1] for positive class
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Binary Classification (Positive vs. Negative)')
plt.legend(loc="lower right")
plt.show()

# %%
# Assuming 2 classes, adjust accordingly
negative_class_index = 0  # Index of the negative class
positive_class_index = 1  # Index of the positive class

# Calculate ROC curve for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(2):
    if i == negative_class_index:
        fpr['negative'], tpr['negative'], _ = roc_curve(y_test_one_hot[:, i], y_pred[:, i])
        roc_auc['negative'] = auc(fpr['negative'], tpr['negative'])
    elif i == positive_class_index:
        fpr['positive'], tpr['positive'], _ = roc_curve(y_test_one_hot[:, i], y_pred[:, i])
        roc_auc['positive'] = auc(fpr['positive'], tpr['positive'])

# Compute micro-average ROC curve and AUC
fpr_micro, tpr_micro, _ = roc_curve(y_test_one_hot.ravel(), y_pred.ravel())
roc_auc_micro = auc(fpr_micro, tpr_micro)

# Compute macro-average ROC curve and AUC
all_fpr = np.unique(np.concatenate([fpr['negative'], fpr['positive']]))
mean_tpr_negative = np.interp(all_fpr, fpr['negative'], tpr['negative'])
mean_tpr_positive = np.interp(all_fpr, fpr['positive'], tpr['positive'])
mean_tpr = (mean_tpr_negative + mean_tpr_positive) / 2
roc_auc_macro = auc(all_fpr, mean_tpr)
# Plot ROC curves
plt.figure(figsize=(10, 6))

# Plot micro-average ROC curve with a solid line
plt.plot(fpr_micro, tpr_micro, label='micro-average ROC curve (area = {:.2f})'.format(roc_auc_micro), linestyle='-', linewidth=2)

# Plot macro-average ROC curve with a solid line
plt.plot(all_fpr, mean_tpr, label='macro-average ROC curve (area = {:.2f})'.format(roc_auc_macro), linestyle='-', linewidth=2)

# Plot individual class ROC curves with different line styles
plt.plot(fpr['negative'], tpr['negative'], label='ROC curve of negative class (area = {:.2f})'.format(roc_auc['negative']), linestyle='--', linewidth=2)
plt.plot(fpr['positive'], tpr['positive'], label='ROC curve of positive class (area = {:.2f})'.format(roc_auc['positive']), linestyle=':', linewidth=2)

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve
# Assuming 2 classes, adjust accordingly
negative_class_index = 0  # Index of the negative class
positive_class_index = 1  # Index of the positive class

# Calculate precision-recall curve for each class
precision = dict()
recall = dict()
pr_auc = dict()

for i in range(2):
    if i == negative_class_index:
        precision['negative'], recall['negative'], _ = precision_recall_curve(y_test_one_hot[:, i], y_pred[:, i])
        pr_auc['negative'] = auc(recall['negative'], precision['negative'])
    elif i == positive_class_index:
        precision['positive'], recall['positive'], _ = precision_recall_curve(y_test_one_hot[:, i], y_pred[:, i])
        pr_auc['positive'] = auc(recall['positive'], precision['positive'])

# Compute micro-average precision-recall curve and AUC
precision["micro"], recall["micro"], _ = precision_recall_curve(y_test_one_hot.ravel(), y_pred.ravel())
pr_auc["micro"] = auc(recall["micro"], precision["micro"])

# Compute macro-average precision-recall curve and AUC
all_recall = np.unique(np.concatenate([recall['negative'], recall['positive']]))
mean_precision_negative = np.interp(all_recall, recall['negative'][::-1], precision['negative'][::-1])
mean_precision_positive = np.interp(all_recall, recall['positive'][::-1], precision['positive'][::-1])
mean_precision = (mean_precision_negative + mean_precision_positive) / 2
precision["macro"] = mean_precision
recall["macro"] = all_recall
pr_auc["macro"] = auc(recall["macro"], precision["macro"])

# Plot Precision-Recall curves
plt.figure(figsize=(10, 6))

# Plot micro-average Precision-Recall curve
plt.plot(recall["micro"], precision["micro"], label='micro-average Precision-Recall curve (area = {:.2f})'.format(pr_auc["micro"]))

# Plot macro-average Precision-Recall curve
plt.plot(recall["macro"], precision["macro"], label='macro-average Precision-Recall curve (area = {:.2f})'.format(pr_auc["macro"]))

# Plot individual class Precision-Recall curves
plt.plot(recall['negative'], precision['negative'], label='Precision-Recall curve of negative class (area = {:.2f})'.format(pr_auc['negative']))
plt.plot(recall['positive'], precision['positive'], label='Precision-Recall curve of positive class (area = {:.2f})'.format(pr_auc['positive']))

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc='lower left')
plt.show()

# %%
# Save the model
model.save('LSTM_final.h5')
from google.colab import files

files.download('LSTM_final.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
